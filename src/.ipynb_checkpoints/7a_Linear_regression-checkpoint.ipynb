# %% [markdown]
# ## 7a. Linear Regression Model Training and Testing
#
# Code are following AAI 540 Lab 4

# %% [markdown]
# ### Setup to Load Data from S3

# %%
# If you're using the default bucket, set DEFAULT_BUCKET = True; otherwise, if you're using a specific bucket, set it to False instead
DEFAULT_BUCKET = False

# %%
# !pip install --upgrade pip

# %%
# !pip install -q PyAthena

# %%
import boto3
import sagemaker
import pandas as pd
from pyathena import connect
sess = sagemaker.Session()
if DEFAULT_BUCKET is True:
    # Code to read/write using the default bucket
    bucket = sess.default_bucket()
else:
    # Code to use a previously existing bucket
    bucket = "usdmsaai540-spring2026-team1"
s3 = boto3.resource("s3")
role = sagemaker.get_execution_role()
region = boto3.Session().region_name
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml

# %%
# Set S3 path to Parquet data
s3_path_parquet = f's3://{bucket}/CCPP/data//parquet'
# Set Athena parameters
# Set Athena parameters
database_name = "ccpp_aws_fp"
table_name_csv = "final_data_csv"
table_name_parquet = "final_data_parquet_v1"

# %%
# Set S3 staging directory -- this is a temporary directory used for Athena queries
s3_staging_dir = "s3://{0}/athena/staging".format(bucket)
s3_staging_dir
# Out:
# 's3://usdmsaai540-spring2026-team1/athena/staging'

# %%
conn = connect(region_name=region, s3_staging_dir=s3_staging_dir)

# %%
from pyathena import connect

# %%
statement = """SELECT count(1) FROM {}.{}
    """.format(
    database_name, table_name_parquet
)

print(statement)
# Out:
# SELECT count(1) FROM ccpp_aws_fp.final_data_parquet_v1

# %%
data_count= pd.read_sql(statement, conn)
total_records=data_count['_col0'].values[0]
total_records
# Out:
# /tmp/ipykernel_1406/3056553487.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data_count= pd.read_sql(statement, conn)
# 14764

# %%
train_seq_id= int(total_records*0.4)
val_seq_id= train_seq_id+ int(total_records*0.4)

# %% [markdown]
# ### Load Training Dataset (all year 2013 data)

# %%
statement = """SELECT * FROM {}.{}
    WHERE seq_id < {}
    ORDER BY seq_id""".format(
    database_name, table_name_parquet,train_seq_id
)

print(statement)
# Out:
# SELECT * FROM ccpp_aws_fp.final_data_parquet_v1
#     WHERE seq_id < 5905
#     ORDER BY seq_id

# %%
data_train = pd.read_sql(statement, conn)
data_train
# Out:
# /tmp/ipykernel_1406/3564220957.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data_train = pd.read_sql(statement, conn)
#       seq_id            ingestion_ts  gt_comp_dis_pressure  \
# 0          1 2026-02-10 02:35:24.729               10.0720
# 1          2 2026-02-10 02:35:24.729               10.3860
# 2          3 2026-02-10 02:35:24.729                9.9408
# 3          4 2026-02-10 02:35:24.729               10.0930
# 4          5 2026-02-10 02:35:24.729               10.0720
# ...      ...                     ...                   ...
# 5899    5900 2026-02-10 02:35:24.729               11.6280
# 5900    5901 2026-02-10 02:35:24.729               11.5870
# 5901    5902 2026-02-10 02:35:24.729               11.6420
# 5902    5903 2026-02-10 02:35:24.729               11.5920
# 5903    5904 2026-02-10 02:35:24.729               11.9850
#
#       gt_exhaust_pressure  gt_inlet_temp  gt_air_filter_diff_pressure  \
# 0                  18.132         1027.8                       2.6356
# 1                  19.480         1006.5                       3.6384
# 2                  17.982         1037.5                       2.5758
# 3                  18.091         1028.7                       2.6372
# 4                  18.232         1026.9                       3.8423
# ...                   ...            ...                          ...
# 5899               25.499         1074.8                       2.9950
# 5900               22.882         1073.6                       3.1950
# 5901               23.971         1076.3                       3.4619
# 5902               22.940         1072.4                       2.9614
# 5903               25.214         1081.1                       3.9441
#
#       solar_radiation  solar_energy  uv_index  gt_ambient_pressure  \
# 0               346.2           1.2       3.0               1024.7
# 1                33.8           0.1       0.0               1017.7
# 2               761.2           2.7       8.0               1013.5
# 3               543.4           2.0       5.0               1023.3
# 4                 0.0           0.0       0.0               1013.7
# ...               ...           ...       ...                  ...
# 5899              0.9           0.0       0.0               1017.2
# 5900              0.0           0.0       0.0               1033.3
# 5901              0.0           0.0       0.0               1012.3
# 5902            456.6           1.6       5.0               1008.1
# 5903              0.0           0.0       0.0               1009.1
#
#       cloud_cover  sea_level_pressure  gt_energy_yield
# 0            24.7              1027.3           100.02
# 1            24.2              1028.0           100.03
# 2            43.4              1017.8           100.04
# 3            27.8              1027.1           100.07
# 4            45.0              1021.9           100.14
# ...           ...                 ...              ...
# 5899         55.7              1009.1           130.13
# 5900         52.3              1018.4           130.13
# 5901          0.0              1019.2           130.13
# 5902         87.9               992.2           130.13
# 5903         78.2              1014.2           130.13
#
# [5904 rows x 13 columns]

# %% [markdown]
# ### Load Validation Data 2014 January

# %%
statement = """SELECT * FROM {}.{}
    WHERE seq_id >= {} and seq_id < {}
    ORDER BY seq_id""".format(
    database_name, table_name_parquet,train_seq_id,val_seq_id
)

print(statement)
# Out:
# SELECT * FROM ccpp_aws_fp.final_data_parquet_v1
#     WHERE seq_id >= 5905 and seq_id < 11810
#     ORDER BY seq_id

# %%
data_val = pd.read_sql(statement, conn)
data_val
# Out:
# /tmp/ipykernel_1406/3443150230.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data_val = pd.read_sql(statement, conn)
#       seq_id            ingestion_ts  gt_comp_dis_pressure  \
# 0       5905 2026-02-10 02:35:24.729                11.795
# 1       5906 2026-02-10 02:35:24.729                11.561
# 2       5907 2026-02-10 02:35:24.729                11.714
# 3       5908 2026-02-10 02:35:24.729                12.017
# 4       5909 2026-02-10 02:35:24.729                11.619
# ...      ...                     ...                   ...
# 5900   11805 2026-02-10 02:35:24.729                13.237
# 5901   11806 2026-02-10 02:35:24.729                13.247
# 5902   11807 2026-02-10 02:35:24.729                13.239
# 5903   11808 2026-02-10 02:35:24.729                13.190
# 5904   11809 2026-02-10 02:35:24.729                13.279
#
#       gt_exhaust_pressure  gt_inlet_temp  gt_air_filter_diff_pressure  \
# 0                  26.317         1070.5                       3.1922
# 1                  23.099         1072.6                       3.0669
# 2                  22.995         1074.1                       3.4150
# 3                  26.025         1082.7                       4.2980
# 4                  28.618         1074.4                       3.1668
# ...                   ...            ...                          ...
# 5900               30.768         1100.0                       5.2301
# 5901               30.777         1099.9                       4.9841
# 5902               30.058         1099.8                       4.6899
# 5903               29.675         1100.0                       4.2717
# 5904               30.233         1099.9                       4.2018
#
#       solar_radiation  solar_energy  uv_index  gt_ambient_pressure  \
# 0               401.0           1.4       4.0               1002.9
# 1                 2.5           0.0       0.0               1008.5
# 2                 0.0           0.0       0.0               1023.2
# 3                 2.6           0.0       0.0               1005.5
# 4               223.1           0.8       2.0               1022.4
# ...               ...           ...       ...                  ...
# 5900            353.4           1.3       4.0               1011.1
# 5901            542.6           2.0       5.0               1005.5
# 5902              0.0           0.0       0.0               1007.2
# 5903              0.0           0.0       0.0               1011.3
# 5904              0.0           0.0       0.0               1013.1
#
#       cloud_cover  sea_level_pressure  gt_energy_yield
# 0            23.9              1024.2           130.13
# 1            89.1               999.3           130.13
# 2             8.8              1028.2           130.14
# 3            89.1              1008.0           130.14
# 4            20.3              1013.2           130.14
# ...           ...                 ...              ...
# 5900         29.3              1010.8           147.96
# 5901         85.5              1012.0           147.96
# 5902         15.8              1009.9           147.96
# 5903         24.0              1012.7           147.96
# 5904         43.6              1010.0           147.96
#
# [5905 rows x 13 columns]

# %% [markdown]
# ### Load Test Data 2014 February

# %%
statement = """SELECT * FROM {}.{}
    WHERE seq_id >= {} 
    ORDER BY seq_id""".format(
    database_name, table_name_parquet,val_seq_id
)

print(statement)
# Out:
# SELECT * FROM ccpp_aws_fp.final_data_parquet_v1
#     WHERE seq_id >= 11810
#     ORDER BY seq_id

# %%
data_test = pd.read_sql(statement, conn)
data_test
# Out:
# /tmp/ipykernel_1406/2304454054.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data_test = pd.read_sql(statement, conn)
#       seq_id            ingestion_ts  gt_comp_dis_pressure  \
# 0      11810 2026-02-10 02:35:24.729                13.206
# 1      11811 2026-02-10 02:35:24.729                13.181
# 2      11812 2026-02-10 02:35:24.729                13.198
# 3      11813 2026-02-10 02:35:24.729                13.233
# 4      11814 2026-02-10 02:35:24.729                13.246
# ...      ...                     ...                   ...
# 2950   14760 2026-02-10 02:35:24.729                15.039
# 2951   14761 2026-02-10 02:35:24.729                15.083
# 2952   14762 2026-02-10 02:35:24.729                15.029
# 2953   14763 2026-02-10 02:35:24.729                15.042
# 2954   14764 2026-02-10 02:35:24.729                15.159
#
#       gt_exhaust_pressure  gt_inlet_temp  gt_air_filter_diff_pressure  \
# 0                  29.560         1099.8                       4.1605
# 1                  30.379         1100.1                       4.7453
# 2                  29.797         1100.1                       4.3650
# 3                  30.344         1098.8                       5.1058
# 4                  30.035         1100.0                       4.7132
# ...                   ...            ...                          ...
# 2950               36.573         1100.0                       4.2813
# 2951               36.533         1100.0                       4.3541
# 2952               37.105         1099.9                       4.3915
# 2953               36.844         1100.0                       4.3749
# 2954               37.505         1099.9                       4.4238
#
#       solar_radiation  solar_energy  uv_index  gt_ambient_pressure  \
# 0                 0.0           0.0       0.0               1012.9
# 1               747.3           2.7       7.0               1012.9
# 2               787.9           2.8       8.0               1015.3
# 3               170.9           0.6       2.0               1012.5
# 4               683.5           2.5       7.0               1013.1
# ...               ...           ...       ...                  ...
# 2950              0.0           0.0       0.0               1033.4
# 2951              0.0           0.0       0.0               1034.1
# 2952              0.0           0.0       0.0               1033.2
# 2953              0.0           0.0       0.0               1034.0
# 2954              0.0           0.0       0.0               1033.3
#
#       cloud_cover  sea_level_pressure  gt_energy_yield
# 0             0.0              1015.0           147.96
# 1             0.0              1009.7           147.97
# 2            14.9              1012.9           147.97
# 3            23.9              1012.7           147.98
# 4            43.6              1016.0           147.98
# ...           ...                 ...              ...
# 2950         20.9              1038.3           177.49
# 2951         89.1              1017.1           177.88
# 2952         87.9              1015.3           177.91
# 2953         89.1              1015.2           178.31
# 2954         83.0              1015.3           179.50
#
# [2955 rows x 13 columns]

# %% [markdown]
# ### Prepare the dataset

# %%
data_train = data_train.drop(['seq_id', 'ingestion_ts'], axis=1)
data_train
# Out:
#       gt_comp_dis_pressure  gt_exhaust_pressure  gt_inlet_temp  \
# 0                  10.0720               18.132         1027.8
# 1                  10.3860               19.480         1006.5
# 2                   9.9408               17.982         1037.5
# 3                  10.0930               18.091         1028.7
# 4                  10.0720               18.232         1026.9
# ...                    ...                  ...            ...
# 5899               11.6280               25.499         1074.8
# 5900               11.5870               22.882         1073.6
# 5901               11.6420               23.971         1076.3
# 5902               11.5920               22.940         1072.4
# 5903               11.9850               25.214         1081.1
#
#       gt_air_filter_diff_pressure  solar_radiation  solar_energy  uv_index  \
# 0                          2.6356            346.2           1.2       3.0
# 1                          3.6384             33.8           0.1       0.0
# 2                          2.5758            761.2           2.7       8.0
# 3                          2.6372            543.4           2.0       5.0
# 4                          3.8423              0.0           0.0       0.0
# ...                           ...              ...           ...       ...
# 5899                       2.9950              0.9           0.0       0.0
# 5900                       3.1950              0.0           0.0       0.0
# 5901                       3.4619              0.0           0.0       0.0
# 5902                       2.9614            456.6           1.6       5.0
# 5903                       3.9441              0.0           0.0       0.0
#
#       gt_ambient_pressure  cloud_cover  sea_level_pressure  gt_energy_yield
# 0                  1024.7         24.7              1027.3           100.02
# 1                  1017.7         24.2              1028.0           100.03
# 2                  1013.5         43.4              1017.8           100.04
# 3                  1023.3         27.8              1027.1           100.07
# 4                  1013.7         45.0              1021.9           100.14
# ...                   ...          ...                 ...              ...
# 5899               1017.2         55.7              1009.1           130.13
# 5900               1033.3         52.3              1018.4           130.13
# 5901               1012.3          0.0              1019.2           130.13
# 5902               1008.1         87.9               992.2           130.13
# 5903               1009.1         78.2              1014.2           130.13
#
# [5904 rows x 11 columns]

# %%
data_val = data_val.drop(['seq_id', 'ingestion_ts'], axis=1)
data_val
# Out:
#       gt_comp_dis_pressure  gt_exhaust_pressure  gt_inlet_temp  \
# 0                   11.795               26.317         1070.5
# 1                   11.561               23.099         1072.6
# 2                   11.714               22.995         1074.1
# 3                   12.017               26.025         1082.7
# 4                   11.619               28.618         1074.4
# ...                    ...                  ...            ...
# 5900                13.237               30.768         1100.0
# 5901                13.247               30.777         1099.9
# 5902                13.239               30.058         1099.8
# 5903                13.190               29.675         1100.0
# 5904                13.279               30.233         1099.9
#
#       gt_air_filter_diff_pressure  solar_radiation  solar_energy  uv_index  \
# 0                          3.1922            401.0           1.4       4.0
# 1                          3.0669              2.5           0.0       0.0
# 2                          3.4150              0.0           0.0       0.0
# 3                          4.2980              2.6           0.0       0.0
# 4                          3.1668            223.1           0.8       2.0
# ...                           ...              ...           ...       ...
# 5900                       5.2301            353.4           1.3       4.0
# 5901                       4.9841            542.6           2.0       5.0
# 5902                       4.6899              0.0           0.0       0.0
# 5903                       4.2717              0.0           0.0       0.0
# 5904                       4.2018              0.0           0.0       0.0
#
#       gt_ambient_pressure  cloud_cover  sea_level_pressure  gt_energy_yield
# 0                  1002.9         23.9              1024.2           130.13
# 1                  1008.5         89.1               999.3           130.13
# 2                  1023.2          8.8              1028.2           130.14
# 3                  1005.5         89.1              1008.0           130.14
# 4                  1022.4         20.3              1013.2           130.14
# ...                   ...          ...                 ...              ...
# 5900               1011.1         29.3              1010.8           147.96
# 5901               1005.5         85.5              1012.0           147.96
# 5902               1007.2         15.8              1009.9           147.96
# 5903               1011.3         24.0              1012.7           147.96
# 5904               1013.1         43.6              1010.0           147.96
#
# [5905 rows x 11 columns]

# %%
data_test = data_test.drop(['seq_id', 'ingestion_ts'], axis=1)
data_test
# Out:
#       gt_comp_dis_pressure  gt_exhaust_pressure  gt_inlet_temp  \
# 0                   13.206               29.560         1099.8
# 1                   13.181               30.379         1100.1
# 2                   13.198               29.797         1100.1
# 3                   13.233               30.344         1098.8
# 4                   13.246               30.035         1100.0
# ...                    ...                  ...            ...
# 2950                15.039               36.573         1100.0
# 2951                15.083               36.533         1100.0
# 2952                15.029               37.105         1099.9
# 2953                15.042               36.844         1100.0
# 2954                15.159               37.505         1099.9
#
#       gt_air_filter_diff_pressure  solar_radiation  solar_energy  uv_index  \
# 0                          4.1605              0.0           0.0       0.0
# 1                          4.7453            747.3           2.7       7.0
# 2                          4.3650            787.9           2.8       8.0
# 3                          5.1058            170.9           0.6       2.0
# 4                          4.7132            683.5           2.5       7.0
# ...                           ...              ...           ...       ...
# 2950                       4.2813              0.0           0.0       0.0
# 2951                       4.3541              0.0           0.0       0.0
# 2952                       4.3915              0.0           0.0       0.0
# 2953                       4.3749              0.0           0.0       0.0
# 2954                       4.4238              0.0           0.0       0.0
#
#       gt_ambient_pressure  cloud_cover  sea_level_pressure  gt_energy_yield
# 0                  1012.9          0.0              1015.0           147.96
# 1                  1012.9          0.0              1009.7           147.97
# 2                  1015.3         14.9              1012.9           147.97
# 3                  1012.5         23.9              1012.7           147.98
# 4                  1013.1         43.6              1016.0           147.98
# ...                   ...          ...                 ...              ...
# 2950               1033.4         20.9              1038.3           177.49
# 2951               1034.1         89.1              1017.1           177.88
# 2952               1033.2         87.9              1015.3           177.91
# 2953               1034.0         89.1              1015.2           178.31
# 2954               1033.3         83.0              1015.3           179.50
#
# [2955 rows x 11 columns]

# %%
data_batch = data_test.drop(['gt_energy_yield'], axis=1)
data_batch
# Out:
#       gt_comp_dis_pressure  gt_exhaust_pressure  gt_inlet_temp  \
# 0                   13.206               29.560         1099.8
# 1                   13.181               30.379         1100.1
# 2                   13.198               29.797         1100.1
# 3                   13.233               30.344         1098.8
# 4                   13.246               30.035         1100.0
# ...                    ...                  ...            ...
# 2950                15.039               36.573         1100.0
# 2951                15.083               36.533         1100.0
# 2952                15.029               37.105         1099.9
# 2953                15.042               36.844         1100.0
# 2954                15.159               37.505         1099.9
#
#       gt_air_filter_diff_pressure  solar_radiation  solar_energy  uv_index  \
# 0                          4.1605              0.0           0.0       0.0
# 1                          4.7453            747.3           2.7       7.0
# 2                          4.3650            787.9           2.8       8.0
# 3                          5.1058            170.9           0.6       2.0
# 4                          4.7132            683.5           2.5       7.0
# ...                           ...              ...           ...       ...
# 2950                       4.2813              0.0           0.0       0.0
# 2951                       4.3541              0.0           0.0       0.0
# 2952                       4.3915              0.0           0.0       0.0
# 2953                       4.3749              0.0           0.0       0.0
# 2954                       4.4238              0.0           0.0       0.0
#
#       gt_ambient_pressure  cloud_cover  sea_level_pressure
# 0                  1012.9          0.0              1015.0
# 1                  1012.9          0.0              1009.7
# 2                  1015.3         14.9              1012.9
# 3                  1012.5         23.9              1012.7
# 4                  1013.1         43.6              1016.0
# ...                   ...          ...                 ...
# 2950               1033.4         20.9              1038.3
# 2951               1034.1         89.1              1017.1
# 2952               1033.2         87.9              1015.3
# 2953               1034.0         89.1              1015.2
# 2954               1033.3         83.0              1015.3
#
# [2955 rows x 10 columns]

# %%
prefix = "CCPP-enery-prediction-linear-regression"

# %%
s3 = boto3.client("s3")

train_file = "train_data.csv"
data_train.to_csv(train_file, index=False, header=False)
#sess.upload_data(train_file, key_prefix="{}/train".format(prefix))
s3.upload_file(train_file, bucket, "{}/train".format(prefix))


validation_file = "validation_data.csv"
data_val.to_csv(validation_file, index=False, header=False)
#sess.upload_data(validation_file, key_prefix="{}/validation".format(prefix))
s3.upload_file(train_file, bucket, "{}/validation".format(prefix))

test_file = "test_data.csv"
data_test.to_csv(test_file, index=False, header=False)
#sess.upload_data(test_file, key_prefix="{}/test".format(prefix))
s3.upload_file(train_file, bucket, "{}/testing".format(prefix))

batch_file = "batch_data.csv"
data_batch.to_csv(batch_file, index=False, header=False)
#sess.upload_data(batch_file, key_prefix="{}/batch".format(prefix))
s3.upload_file(train_file, bucket, "{}/batch".format(prefix))

# %% [markdown]
# ### Model Training Setup and Training

# %%
# %%time
from time import gmtime, strftime

job_name = "lr-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())
output_location = "s3://{}/{}/output/{}".format(bucket, prefix, job_name)
image = sagemaker.image_uris.retrieve(
    framework="linear-learner",   # built-in algorithm for regression/classification
    region=boto3.Session().region_name,
    version="latest"               # always safe to use "latest"
)

linear_estimator = sagemaker.estimator.Estimator(
    image,
    role,
    instance_count=1,
    instance_type="ml.m5.large",
    volume_size=50,
    input_mode="File",
    output_path=output_location,
    sagemaker_session=sess,
)
linear_estimator.set_hyperparameters(
    predictor_type="regressor",   # must set this for regression
    mini_batch_size=100,          # batch size for training
    epochs=15,                    # number of passes over the dataset
    learning_rate=0.01,           # similar to eta
    optimizer="adam"              # can also be 'sgd', 'ftrl'
)
train_data = sagemaker.inputs.TrainingInput(
    "s3://{}/{}/train".format(bucket, prefix),
    distribution="FullyReplicated",
    content_type="text/csv",
    s3_data_type="S3Prefix",
)
validation_data = sagemaker.inputs.TrainingInput(
    "s3://{}/{}/validation".format(bucket, prefix),
    distribution="FullyReplicated",
    content_type="text/csv",
    s3_data_type="S3Prefix",
)
data_channels = {"train": train_data, "validation": validation_data}

# Start training by calling the fit method in the estimator
linear_estimator.fit(inputs=data_channels, job_name=job_name, logs=True)
# Out:
# INFO:sagemaker.image_uris:Same images used for training and inference. Defaulting to image scope: inference.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker.telemetry.telemetry_logging:SageMaker Python SDK will collect telemetry to help us better understand our user's needs, diagnose issues, and deliver additional features.
# To opt out of telemetry, please disable via TelemetryOptOut parameter in SDK defaults config. For more information, refer to https://sagemaker.readthedocs.io/en/stable/overview.html#configuring-and-using-defaults-with-the-sagemaker-python-sdk.
# INFO:sagemaker:Creating training-job with name: lr-2026-02-10-06-08-01
# 2026-02-10 06:08:01 Starting - Starting the training job...
# 2026-02-10 06:08:27 Starting - Preparing the instances for training...
# 2026-02-10 06:08:51 Downloading - Downloading input data...
# 2026-02-10 06:09:31 Downloading - Downloading the training image.........
# 2026-02-10 06:10:53 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [02/10/2026 06:10:57 INFO 140012197074752] Reading default configuration from /opt/amazon/lib/python3.8/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [02/10/2026 06:10:57 INFO 140012197074752] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'epochs': '15', 'learning_rate': '0.01', 'mini_batch_size': '100', 'optimizer': 'adam', 'predictor_type': 'regressor'}
# [02/10/2026 06:10:57 INFO 140012197074752] Final configuration: {'mini_batch_size': '100', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'adam', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': '0.01', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# /opt/amazon/lib/python3.8/site-packages/mxnet/model.py:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if num_device is 1 and 'dist' not in kvstore:
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:495: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if cons['type'] is 'ineq':
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:743: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if len(self.X_min) is not 0:
# [02/10/2026 06:11:00 WARNING 140012197074752] Loggers have already been setup.
# [02/10/2026 06:11:00 INFO 140012197074752] Final configuration: {'mini_batch_size': '100', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'adam', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': '0.01', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# [02/10/2026 06:11:00 WARNING 140012197074752] Loggers have already been setup.
# Process 7 is a worker.
# [02/10/2026 06:11:00 INFO 140012197074752] Using default worker.
# [02/10/2026 06:11:00 INFO 140012197074752] Checkpoint loading and saving are disabled.
# [02/10/2026 06:11:00 INFO 140012197074752] Create Store: local
# [02/10/2026 06:11:00 INFO 140012197074752] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f5699e9e580>
# [02/10/2026 06:11:00 INFO 140012197074752] Scaling model computed with parameters:
#  {'stdev_label':
# [0.5951832]
# <NDArray 1 @cpu(0)>, 'stdev_weight':
# [  2.356576   14.52003     0.5808528 239.63835     0.8630341   2.412217
#    6.7337065  35.591595    6.2241187   8.689489 ]
# <NDArray 10 @cpu(0)>, 'mean_label':
# [11.124606]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [2.24065189e+01 1.06191333e+03 3.30584455e+00 1.50948196e+02
#  5.43050826e-01 1.50491548e+00 1.01363617e+03 4.82792969e+01
#  1.01613214e+03 1.19480209e+02]
# <NDArray 10 @cpu(0)>}
# /opt/amazon/python3.8/lib/python3.8/subprocess.py:848: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdout = io.open(c2pread, 'rb', bufsize)
# [02/10/2026 06:11:00 INFO 140012197074752] nvidia-smi: took 0.033 seconds to run.
# [02/10/2026 06:11:00 INFO 140012197074752] nvidia-smi identified 0 GPUs.
# [02/10/2026 06:11:00 INFO 140012197074752] Number of GPUs being used: 0
# #metrics {"StartTime": 1770703860.8624458, "EndTime": 1770703860.8624787, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 6004.0, "count": 1, "min": 6004, "max": 6004}, "Total Batches Seen": {"sum": 61.0, "count": 1, "min": 61, "max": 61}, "Max Records Seen Between Resets": {"sum": 5904.0, "count": 1, "min": 5904, "max": 5904}, "Max Batches Seen Between Resets": {"sum": 60.0, "count": 1, "min": 60, "max": 60}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# #metrics {"StartTime": 1770703861.9871786, "EndTime": 1770703861.9872565, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.3114723455097716, "count": 1, "min": 0.3114723455097716, "max": 0.3114723455097716}}}
# #metrics {"StartTime": 1770703861.9873502, "EndTime": 1770703861.9873655, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.5130161187608363, "count": 1, "min": 0.5130161187608363, "max": 0.5130161187608363}}}
# #metrics {"StartTime": 1770703861.9874086, "EndTime": 1770703861.9874187, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 0.6081793100146924, "count": 1, "min": 0.6081793100146924, "max": 0.6081793100146924}}}
# #metrics {"StartTime": 1770703861.9874504, "EndTime": 1770703861.9874592, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.6876694440033476, "count": 1, "min": 0.6876694440033476, "max": 0.6876694440033476}}}
# #metrics {"StartTime": 1770703861.9874911, "EndTime": 1770703861.9874992, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.21164681289155604, "count": 1, "min": 0.21164681289155604, "max": 0.21164681289155604}}}
# #metrics {"StartTime": 1770703861.987535, "EndTime": 1770703861.9875445, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 0.23075124207189526, "count": 1, "min": 0.23075124207189526, "max": 0.23075124207189526}}}
# #metrics {"StartTime": 1770703861.987578, "EndTime": 1770703861.9875865, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.23836714045476104, "count": 1, "min": 0.23836714045476104, "max": 0.23836714045476104}}}
# #metrics {"StartTime": 1770703861.9876146, "EndTime": 1770703861.9876223, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 0.21714266639644816, "count": 1, "min": 0.21714266639644816, "max": 0.21714266639644816}}}
# #metrics {"StartTime": 1770703861.9876516, "EndTime": 1770703861.9876595, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.4930889456554995, "count": 1, "min": 0.4930889456554995, "max": 0.4930889456554995}}}
# #metrics {"StartTime": 1770703861.9876873, "EndTime": 1770703861.9876955, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 0.35509989972841943, "count": 1, "min": 0.35509989972841943, "max": 0.35509989972841943}}}
# #metrics {"StartTime": 1770703861.987726, "EndTime": 1770703861.9877343, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.6353157728809421, "count": 1, "min": 0.6353157728809421, "max": 0.6353157728809421}}}
# #metrics {"StartTime": 1770703861.9877672, "EndTime": 1770703861.9877756, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 0.5207308263697866, "count": 1, "min": 0.5207308263697866, "max": 0.5207308263697866}}}
# #metrics {"StartTime": 1770703861.9878066, "EndTime": 1770703861.9878156, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.2381182883553586, "count": 1, "min": 0.2381182883553586, "max": 0.2381182883553586}}}
# #metrics {"StartTime": 1770703861.9878488, "EndTime": 1770703861.9878576, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.17656314053777922, "count": 1, "min": 0.17656314053777922, "max": 0.17656314053777922}}}
# #metrics {"StartTime": 1770703861.9878905, "EndTime": 1770703861.9878993, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.2208765470375449, "count": 1, "min": 0.2208765470375449, "max": 0.2208765470375449}}}
# #metrics {"StartTime": 1770703861.9879332, "EndTime": 1770703861.9879422, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 0.2473792588104636, "count": 1, "min": 0.2473792588104636, "max": 0.2473792588104636}}}
# #metrics {"StartTime": 1770703861.9879754, "EndTime": 1770703861.9879854, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.694641502994602, "count": 1, "min": 0.694641502994602, "max": 0.694641502994602}}}
# #metrics {"StartTime": 1770703861.9880202, "EndTime": 1770703861.9880285, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.5952208654759293, "count": 1, "min": 0.5952208654759293, "max": 0.5952208654759293}}}
# #metrics {"StartTime": 1770703861.9880614, "EndTime": 1770703861.9880695, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 0.7567416760072869, "count": 1, "min": 0.7567416760072869, "max": 0.7567416760072869}}}
# #metrics {"StartTime": 1770703861.9881003, "EndTime": 1770703861.9881094, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.6769091556031825, "count": 1, "min": 0.6769091556031825, "max": 0.6769091556031825}}}
# #metrics {"StartTime": 1770703861.9881413, "EndTime": 1770703861.988149, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.22307826284634866, "count": 1, "min": 0.22307826284634866, "max": 0.22307826284634866}}}
# #metrics {"StartTime": 1770703861.9881794, "EndTime": 1770703861.988187, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 0.19855392157021215, "count": 1, "min": 0.19855392157021215, "max": 0.19855392157021215}}}
# #metrics {"StartTime": 1770703861.9882183, "EndTime": 1770703861.9882271, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 0.21954137939517782, "count": 1, "min": 0.21954137939517782, "max": 0.21954137939517782}}}
# #metrics {"StartTime": 1770703861.9882615, "EndTime": 1770703861.9882703, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 0.229482553288088, "count": 1, "min": 0.229482553288088, "max": 0.229482553288088}}}
# #metrics {"StartTime": 1770703861.9883008, "EndTime": 1770703861.98831, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 0.960423323421155, "count": 1, "min": 0.960423323421155, "max": 0.960423323421155}}}
# #metrics {"StartTime": 1770703861.9883437, "EndTime": 1770703861.988353, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 1.00002736536123, "count": 1, "min": 1.00002736536123, "max": 1.00002736536123}}}
# #metrics {"StartTime": 1770703861.9883873, "EndTime": 1770703861.9883957, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 1.0767430701498257, "count": 1, "min": 1.0767430701498257, "max": 1.0767430701498257}}}
# #metrics {"StartTime": 1770703861.9884293, "EndTime": 1770703861.9884384, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 1.0415362672482507, "count": 1, "min": 1.0415362672482507, "max": 1.0415362672482507}}}
# #metrics {"StartTime": 1770703861.9884715, "EndTime": 1770703861.98848, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 0.1898212954553507, "count": 1, "min": 0.1898212954553507, "max": 0.1898212954553507}}}
# #metrics {"StartTime": 1770703861.9885154, "EndTime": 1770703861.988525, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 0.18153890795626884, "count": 1, "min": 0.18153890795626884, "max": 0.18153890795626884}}}
# #metrics {"StartTime": 1770703861.9885585, "EndTime": 1770703861.9885674, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 0.1649012688054877, "count": 1, "min": 0.1649012688054877, "max": 0.1649012688054877}}}
# #metrics {"StartTime": 1770703861.9885979, "EndTime": 1770703861.9886067, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 0.16609557325557125, "count": 1, "min": 0.16609557325557125, "max": 0.16609557325557125}}}
# [02/10/2026 06:11:01 INFO 140012197074752] #quality_metric: host=algo-1, epoch=0, train mse_objective <loss>=0.3114723455097716
# #metrics {"StartTime": 1770703862.6438446, "EndTime": 1770703862.6438928, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 0.31316231481660267, "count": 1, "min": 0.31316231481660267, "max": 0.31316231481660267}}}
# #metrics {"StartTime": 1770703862.6439626, "EndTime": 1770703862.6439743, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 0.1514009410139365, "count": 1, "min": 0.1514009410139365, "max": 0.1514009410139365}}}
# #metrics {"StartTime": 1770703862.6440146, "EndTime": 1770703862.6440258, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 0.1524321683102002, "count": 1, "min": 0.1524321683102002, "max": 0.1524321683102002}}}
# #metrics {"StartTime": 1770703862.6440642, "EndTime": 1770703862.6440742, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 0.16254867305398635, "count": 1, "min": 0.16254867305398635, "max": 0.16254867305398635}}}
# #metrics {"StartTime": 1770703862.644113, "EndTime": 1770703862.6441236, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 0.2926829962989285, "count": 1, "min": 0.2926829962989285, "max": 0.2926829962989285}}}
# #metrics {"StartTime": 1770703862.644161, "EndTime": 1770703862.6441712, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 0.35788035435036714, "count": 1, "min": 0.35788035435036714, "max": 0.35788035435036714}}}
# #metrics {"StartTime": 1770703862.6442058, "EndTime": 1770703862.6442134, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 0.31206683210680275, "count": 1, "min": 0.31206683210680275, "max": 0.31206683210680275}}}
# #metrics {"StartTime": 1770703862.6442423, "EndTime": 1770703862.6442497, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 0.24132793390086088, "count": 1, "min": 0.24132793390086088, "max": 0.24132793390086088}}}
# #metrics {"StartTime": 1770703862.6442852, "EndTime": 1770703862.644293, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 0.13890437275388337, "count": 1, "min": 0.13890437275388337, "max": 0.13890437275388337}}}
# #metrics {"StartTime": 1770703862.6443198, "EndTime": 1770703862.6443264, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 0.14380184385728667, "count": 1, "min": 0.14380184385728667, "max": 0.14380184385728667}}}
# #metrics {"StartTime": 1770703862.6443555, "EndTime": 1770703862.6443627, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 0.14959142730901961, "count": 1, "min": 0.14959142730901961, "max": 0.14959142730901961}}}
# #metrics {"StartTime": 1770703862.6443899, "EndTime": 1770703862.6443985, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 0.15367420019612202, "count": 1, "min": 0.15367420019612202, "max": 0.15367420019612202}}}
# #metrics {"StartTime": 1770703862.6444354, "EndTime": 1770703862.6444454, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 0.26214808245318205, "count": 1, "min": 0.26214808245318205, "max": 0.26214808245318205}}}
# #metrics {"StartTime": 1770703862.6444821, "EndTime": 1770703862.6444917, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 0.35445873414577667, "count": 1, "min": 0.35445873414577667, "max": 0.35445873414577667}}}
# #metrics {"StartTime": 1770703862.644529, "EndTime": 1770703862.644538, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 0.312665527370988, "count": 1, "min": 0.312665527370988, "max": 0.312665527370988}}}
# #metrics {"StartTime": 1770703862.644571, "EndTime": 1770703862.6445808, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 0.367202852101464, "count": 1, "min": 0.367202852101464, "max": 0.367202852101464}}}
# #metrics {"StartTime": 1770703862.6446195, "EndTime": 1770703862.6446297, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 0.16905056277345512, "count": 1, "min": 0.16905056277345512, "max": 0.16905056277345512}}}
# #metrics {"StartTime": 1770703862.644665, "EndTime": 1770703862.6446743, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 0.17551345954621386, "count": 1, "min": 0.17551345954621386, "max": 0.17551345954621386}}}
# #metrics {"StartTime": 1770703862.644708, "EndTime": 1770703862.6447165, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 0.1724995817322799, "count": 1, "min": 0.1724995817322799, "max": 0.1724995817322799}}}
# #metrics {"StartTime": 1770703862.644756, "EndTime": 1770703862.6447659, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 0.1810438767539938, "count": 1, "min": 0.1810438767539938, "max": 0.1810438767539938}}}
# #metrics {"StartTime": 1770703862.6448007, "EndTime": 1770703862.64481, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 0.6381740695064974, "count": 1, "min": 0.6381740695064974, "max": 0.6381740695064974}}}
# #metrics {"StartTime": 1770703862.6448433, "EndTime": 1770703862.6448522, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 0.6762481213390807, "count": 1, "min": 0.6762481213390807, "max": 0.6762481213390807}}}
# #metrics {"StartTime": 1770703862.6448915, "EndTime": 1770703862.6449015, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 0.6528127682836964, "count": 1, "min": 0.6528127682836964, "max": 0.6528127682836964}}}
# #metrics {"StartTime": 1770703862.6449347, "EndTime": 1770703862.644944, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 0.6711976907258919, "count": 1, "min": 0.6711976907258919, "max": 0.6711976907258919}}}
# #metrics {"StartTime": 1770703862.6449833, "EndTime": 1770703862.644993, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 0.42962182814957006, "count": 1, "min": 0.42962182814957006, "max": 0.42962182814957006}}}
# #metrics {"StartTime": 1770703862.645032, "EndTime": 1770703862.6450415, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 0.4308702041745832, "count": 1, "min": 0.4308702041745832, "max": 0.4308702041745832}}}
# #metrics {"StartTime": 1770703862.6450813, "EndTime": 1770703862.6450913, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 0.40409662925857837, "count": 1, "min": 0.40409662925857837, "max": 0.40409662925857837}}}
# #metrics {"StartTime": 1770703862.6451283, "EndTime": 1770703862.6451383, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 0.4235053398724655, "count": 1, "min": 0.4235053398724655, "max": 0.4235053398724655}}}
# #metrics {"StartTime": 1770703862.6451747, "EndTime": 1770703862.6451833, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 0.8251974751546898, "count": 1, "min": 0.8251974751546898, "max": 0.8251974751546898}}}
# #metrics {"StartTime": 1770703862.6452146, "EndTime": 1770703862.6452458, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 0.7593115669470735, "count": 1, "min": 0.7593115669470735, "max": 0.7593115669470735}}}
# #metrics {"StartTime": 1770703862.6452863, "EndTime": 1770703862.6452968, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"validation_mse_objective": {"sum": 0.7878791543990777, "count": 1, "min": 0.7878791543990777, "max": 0.7878791543990777}}}
# #metrics {"StartTime": 1770703862.6453342, "EndTime": 1770703862.645343, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"validation_mse_objective": {"sum": 0.7633280590565265, "count": 1, "min": 0.7633280590565265, "max": 0.7633280590565265}}}
# [02/10/2026 06:11:02 INFO 140012197074752] #quality_metric: host=algo-1, epoch=0, validation mse_objective <loss>=0.31316231481660267
# [02/10/2026 06:11:02 INFO 140012197074752] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=mse_objective, value=0.13890437275388337
# [02/10/2026 06:11:02 INFO 140012197074752] Epoch 0: Loss improved. Updating best model
# [02/10/2026 06:11:02 INFO 140012197074752] Saving model for epoch: 0
# [02/10/2026 06:11:02 INFO 140012197074752] Saved checkpoint to "/tmp/tmpogvsh160/mx-mod-0000.params"
# [02/10/2026 06:11:02 INFO 140012197074752] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1770703860.862734, "EndTime": 1770703862.6537385, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 11908.0, "count": 1, "min": 11908, "max": 11908}, "Total Batches Seen": {"sum": 121.0, "count": 1, "min": 121, "max": 121}, "Max Records Seen Between Resets": {"sum": 5904.0, "count": 1, "min": 5904, "max": 5904}, "Max Batches Seen Between Resets": {"sum": 60.0, "count": 1, "min": 60, "max": 60}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 5904.0, "count": 1, "min": 5904, "max": 5904}, "Number of Batches Since Last Reset": {"sum": 60.0, "count": 1, "min": 60, "max": 60}}}
# [02/10/2026 06:11:02 INFO 140012197074752] #throughput_metric: host=algo-1, train throughput=3296.2526853165955 records/second
# #metrics {"StartTime": 1770703863.6648889, "EndTime": 1770703863.664934, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.3286852782055483, "count": 1, "min": 0.3286852782055483, "max": 0.3286852782055483}}}
# #metrics {"StartTime": 1770703863.6649995, "EndTime": 1770703863.6650112, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.24716587664717335, "count": 1, "min": 0.24716587664717335, "max": 0.24716587664717335}}}
# #metrics {"StartTime": 1770703863.6650522, "EndTime": 1770703863.6650631, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 0.2842076301170608, "count": 1, "min": 0.2842076301170608, "max": 0.2842076301170608}}}
# #metrics {"StartTime": 1770703863.665125, "EndTime": 1770703863.6651368, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.29560672578165087, "count": 1, "min": 0.29560672578165087, "max": 0.29560672578165087}}}
# #metrics {"StartTime": 1770703863.6652012, "EndTime": 1770703863.6652114, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.23751902170100456, "count": 1, "min": 0.23751902170100456, "max": 0.23751902170100456}}}
# #metrics {"StartTime": 1770703863.6652875, "EndTime": 1770703863.6652997, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 0.2992565812094737, "count": 1, "min": 0.2992565812094737, "max": 0.2992565812094737}}}
# #metrics {"StartTime": 1770703863.6654313, "EndTime": 1770703863.6654484, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.2634869725017224, "count": 1, "min": 0.2634869725017224, "max": 0.2634869725017224}}}
# #metrics {"StartTime": 1770703863.6655183, "EndTime": 1770703863.6655312, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 0.20027263906042456, "count": 1, "min": 0.20027263906042456, "max": 0.20027263906042456}}}
# #metrics {"StartTime": 1770703863.6655993, "EndTime": 1770703863.6656122, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.23547940674474685, "count": 1, "min": 0.23547940674474685, "max": 0.23547940674474685}}}
# #metrics {"StartTime": 1770703863.6656775, "EndTime": 1770703863.6656904, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 0.20138652112524388, "count": 1, "min": 0.20138652112524388, "max": 0.20138652112524388}}}
# #metrics {"StartTime": 1770703863.665761, "EndTime": 1770703863.665774, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.2800776458190659, "count": 1, "min": 0.2800776458190659, "max": 0.2800776458190659}}}
# #metrics {"StartTime": 1770703863.6658425, "EndTime": 1770703863.6658556, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 0.254922210321588, "count": 1, "min": 0.254922210321588, "max": 0.254922210321588}}}
# #metrics {"StartTime": 1770703863.665924, "EndTime": 1770703863.6659374, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.21768425715171685, "count": 1, "min": 0.21768425715171685, "max": 0.21768425715171685}}}
# #metrics {"StartTime": 1770703863.6660032, "EndTime": 1770703863.6660163, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.28673602209252824, "count": 1, "min": 0.28673602209252824, "max": 0.28673602209252824}}}
# #metrics {"StartTime": 1770703863.6660576, "EndTime": 1770703863.6660895, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.2580006092887814, "count": 1, "min": 0.2580006092887814, "max": 0.2580006092887814}}}
# #metrics {"StartTime": 1770703863.6661284, "EndTime": 1770703863.6661367, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 0.30988869448839607, "count": 1, "min": 0.30988869448839607, "max": 0.30988869448839607}}}
# #metrics {"StartTime": 1770703863.6661665, "EndTime": 1770703863.6661737, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.34335420507495684, "count": 1, "min": 0.34335420507495684, "max": 0.34335420507495684}}}
# #metrics {"StartTime": 1770703863.6662009, "EndTime": 1770703863.6662078, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.31957993992304395, "count": 1, "min": 0.31957993992304395, "max": 0.31957993992304395}}}
# #metrics {"StartTime": 1770703863.666235, "EndTime": 1770703863.666242, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 0.3542047551930961, "count": 1, "min": 0.3542047551930961, "max": 0.3542047551930961}}}
# #metrics {"StartTime": 1770703863.6662688, "EndTime": 1770703863.6662757, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.3440853668471514, "count": 1, "min": 0.3440853668471514, "max": 0.3440853668471514}}}
# #metrics {"StartTime": 1770703863.6663036, "EndTime": 1770703863.6663105, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.532114053904, "count": 1, "min": 0.532114053904, "max": 0.532114053904}}}
# #metrics {"StartTime": 1770703863.666338, "EndTime": 1770703863.666345, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 0.5313170577711979, "count": 1, "min": 0.5313170577711979, "max": 0.5313170577711979}}}
# #metrics {"StartTime": 1770703863.6663723, "EndTime": 1770703863.6663797, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 0.5335934386010898, "count": 1, "min": 0.5335934386010898, "max": 0.5335934386010898}}}
# #metrics {"StartTime": 1770703863.666407, "EndTime": 1770703863.6664143, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 0.5331563789561643, "count": 1, "min": 0.5331563789561643, "max": 0.5331563789561643}}}
# #metrics {"StartTime": 1770703863.666441, "EndTime": 1770703863.6664479, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 1.2872195952625598, "count": 1, "min": 1.2872195952625598, "max": 1.2872195952625598}}}
# #metrics {"StartTime": 1770703863.6664743, "EndTime": 1770703863.6664815, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 1.2990456698708615, "count": 1, "min": 1.2990456698708615, "max": 1.2990456698708615}}}
# #metrics {"StartTime": 1770703863.666512, "EndTime": 1770703863.66652, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 1.2543027233269255, "count": 1, "min": 1.2543027233269255, "max": 1.2543027233269255}}}
# #metrics {"StartTime": 1770703863.6665485, "EndTime": 1770703863.6665561, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 1.2864641920994904, "count": 1, "min": 1.2864641920994904, "max": 1.2864641920994904}}}
# #metrics {"StartTime": 1770703863.6665974, "EndTime": 1770703863.6666055, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 0.6445924520088454, "count": 1, "min": 0.6445924520088454, "max": 0.6445924520088454}}}
# #metrics {"StartTime": 1770703863.666636, "EndTime": 1770703863.6666436, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 0.6172215628219863, "count": 1, "min": 0.6172215628219863, "max": 0.6172215628219863}}}
# #metrics {"StartTime": 1770703863.666674, "EndTime": 1770703863.6666813, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 0.6186159394151073, "count": 1, "min": 0.6186159394151073, "max": 0.6186159394151073}}}
# #metrics {"StartTime": 1770703863.6667113, "EndTime": 1770703863.6667185, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 0.6162393502865807, "count": 1, "min": 0.6162393502865807, "max": 0.6162393502865807}}}
# [02/10/2026 06:11:03 INFO 140012197074752] #quality_metric: host=algo-1, epoch=1, train mse_objective <loss>=0.3286852782055483
# #metrics {"StartTime": 1770703864.3225543, "EndTime": 1770703864.3226404, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 0.037958029560431795, "count": 1, "min": 0.037958029560431795, "max": 0.037958029560431795}}}
# #metrics {"StartTime": 1770703864.322737, "EndTime": 1770703864.3227525, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 0.016330858889707242, "count": 1, "min": 0.016330858889707242, "max": 0.016330858889707242}}}
# #metrics {"StartTime": 1770703864.3228433, "EndTime": 1770703864.3228586, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 0.021061260939694355, "count": 1, "min": 0.021061260939694355, "max": 0.021061260939694355}}}
# #metrics {"StartTime": 1770703864.3229287, "EndTime": 1770703864.3229415, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 0.018955033930614186, "count": 1, "min": 0.018955033930614186, "max": 0.018955033930614186}}}
# #metrics {"StartTime": 1770703864.3230028, "EndTime": 1770703864.3230162, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 0.03925896620694649, "count": 1, "min": 0.03925896620694649, "max": 0.03925896620694649}}}
# #metrics {"StartTime": 1770703864.3230772, "EndTime": 1770703864.3230922, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 0.034344296700505386, "count": 1, "min": 0.034344296700505386, "max": 0.034344296700505386}}}
# #metrics {"StartTime": 1770703864.3231332, "EndTime": 1770703864.3231678, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 0.05551135969199341, "count": 1, "min": 0.05551135969199341, "max": 0.05551135969199341}}}
# #metrics {"StartTime": 1770703864.3232136, "EndTime": 1770703864.3232486, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 0.031517049494555326, "count": 1, "min": 0.031517049494555326, "max": 0.031517049494555326}}}
# #metrics {"StartTime": 1770703864.3232906, "EndTime": 1770703864.323324, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 0.01654365578846789, "count": 1, "min": 0.01654365578846789, "max": 0.01654365578846789}}}
# #metrics {"StartTime": 1770703864.3233645, "EndTime": 1770703864.3233757, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 0.016175027580825778, "count": 1, "min": 0.016175027580825778, "max": 0.016175027580825778}}}
# #metrics {"StartTime": 1770703864.3234372, "EndTime": 1770703864.3234491, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 0.02006330328418048, "count": 1, "min": 0.02006330328418048, "max": 0.02006330328418048}}}
# #metrics {"StartTime": 1770703864.3235126, "EndTime": 1770703864.3235252, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 0.01801807276316512, "count": 1, "min": 0.01801807276316512, "max": 0.01801807276316512}}}
# #metrics {"StartTime": 1770703864.3236692, "EndTime": 1770703864.3236976, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 0.04824854875378422, "count": 1, "min": 0.04824854875378422, "max": 0.04824854875378422}}}
# #metrics {"StartTime": 1770703864.3237665, "EndTime": 1770703864.3237796, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 0.023519082892140965, "count": 1, "min": 0.023519082892140965, "max": 0.023519082892140965}}}
# #metrics {"StartTime": 1770703864.3238492, "EndTime": 1770703864.3238623, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 0.04811161389223585, "count": 1, "min": 0.04811161389223585, "max": 0.04811161389223585}}}
# #metrics {"StartTime": 1770703864.3239357, "EndTime": 1770703864.3239892, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 0.06332667728792624, "count": 1, "min": 0.06332667728792624, "max": 0.06332667728792624}}}
# #metrics {"StartTime": 1770703864.3240924, "EndTime": 1770703864.3241074, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 0.045672217184591905, "count": 1, "min": 0.045672217184591905, "max": 0.045672217184591905}}}
# #metrics {"StartTime": 1770703864.3242233, "EndTime": 1770703864.324239, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 0.04083176189087089, "count": 1, "min": 0.04083176189087089, "max": 0.04083176189087089}}}
# #metrics {"StartTime": 1770703864.32433, "EndTime": 1770703864.324343, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 0.04609928288948811, "count": 1, "min": 0.04609928288948811, "max": 0.04609928288948811}}}
# #metrics {"StartTime": 1770703864.3244216, "EndTime": 1770703864.3244739, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 0.04347807805616721, "count": 1, "min": 0.04347807805616721, "max": 0.04347807805616721}}}
# #metrics {"StartTime": 1770703864.3245583, "EndTime": 1770703864.3245723, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 0.8076143296824158, "count": 1, "min": 0.8076143296824158, "max": 0.8076143296824158}}}
# ...
# #metrics {"StartTime": 1770703881.2514882, "EndTime": 1770703881.2514966, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 0.5539789371167199, "count": 1, "min": 0.5539789371167199, "max": 0.5539789371167199}}}
# [02/10/2026 06:11:21 INFO 140012197074752] #quality_metric: host=algo-1, epoch=11, train mse_objective <loss>=0.03072977084224507
# #metrics {"StartTime": 1770703881.8314092, "EndTime": 1770703881.8314846, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 0.012454867145919864, "count": 1, "min": 0.012454867145919864, "max": 0.012454867145919864}}}
# #metrics {"StartTime": 1770703881.8315732, "EndTime": 1770703881.8315885, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 0.011853867072894726, "count": 1, "min": 0.011853867072894726, "max": 0.011853867072894726}}}
# #metrics {"StartTime": 1770703881.8316295, "EndTime": 1770703881.8316386, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 0.011739699776362638, "count": 1, "min": 0.011739699776362638, "max": 0.011739699776362638}}}
# #metrics {"StartTime": 1770703881.8316734, "EndTime": 1770703881.8316832, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 0.011817164152171614, "count": 1, "min": 0.011817164152171614, "max": 0.011817164152171614}}}
# #metrics {"StartTime": 1770703881.8317132, "EndTime": 1770703881.8317213, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 0.01228612170934546, "count": 1, "min": 0.01228612170934546, "max": 0.01228612170934546}}}
# #metrics {"StartTime": 1770703881.8317509, "EndTime": 1770703881.8317595, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 0.016709967685464597, "count": 1, "min": 0.016709967685464597, "max": 0.016709967685464597}}}
# #metrics {"StartTime": 1770703881.831789, "EndTime": 1770703881.831797, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 0.012355756278965006, "count": 1, "min": 0.012355756278965006, "max": 0.012355756278965006}}}
# #metrics {"StartTime": 1770703881.8318276, "EndTime": 1770703881.831836, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 0.022964527309294235, "count": 1, "min": 0.022964527309294235, "max": 0.022964527309294235}}}
# #metrics {"StartTime": 1770703881.831866, "EndTime": 1770703881.8318746, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 0.01146976137502235, "count": 1, "min": 0.01146976137502235, "max": 0.01146976137502235}}}
# #metrics {"StartTime": 1770703881.8319066, "EndTime": 1770703881.831914, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 0.013097624560732263, "count": 1, "min": 0.013097624560732263, "max": 0.013097624560732263}}}
# #metrics {"StartTime": 1770703881.8319428, "EndTime": 1770703881.8319507, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 0.011771593874807503, "count": 1, "min": 0.011771593874807503, "max": 0.011771593874807503}}}
# #metrics {"StartTime": 1770703881.831981, "EndTime": 1770703881.8319886, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 0.012805806855900784, "count": 1, "min": 0.012805806855900784, "max": 0.012805806855900784}}}
# #metrics {"StartTime": 1770703881.8320165, "EndTime": 1770703881.832024, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 0.024821573074624386, "count": 1, "min": 0.024821573074624386, "max": 0.024821573074624386}}}
# #metrics {"StartTime": 1770703881.8320572, "EndTime": 1770703881.8320653, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 0.024251005488642185, "count": 1, "min": 0.024251005488642185, "max": 0.024251005488642185}}}
# #metrics {"StartTime": 1770703881.832097, "EndTime": 1770703881.8321044, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 0.024108400731789187, "count": 1, "min": 0.024108400731789187, "max": 0.024108400731789187}}}
# #metrics {"StartTime": 1770703881.832133, "EndTime": 1770703881.8321416, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 0.031627241127712896, "count": 1, "min": 0.031627241127712896, "max": 0.031627241127712896}}}
# #metrics {"StartTime": 1770703881.8321714, "EndTime": 1770703881.8321793, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 0.042366425405814236, "count": 1, "min": 0.042366425405814236, "max": 0.042366425405814236}}}
# #metrics {"StartTime": 1770703881.8322082, "EndTime": 1770703881.8322153, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 0.09885895034256656, "count": 1, "min": 0.09885895034256656, "max": 0.09885895034256656}}}
# #metrics {"StartTime": 1770703881.8322458, "EndTime": 1770703881.832254, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 0.04195910290534782, "count": 1, "min": 0.04195910290534782, "max": 0.04195910290534782}}}
# #metrics {"StartTime": 1770703881.8322847, "EndTime": 1770703881.8322923, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 0.09601185742518321, "count": 1, "min": 0.09601185742518321, "max": 0.09601185742518321}}}
# #metrics {"StartTime": 1770703881.8323228, "EndTime": 1770703881.83233, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 0.5737717915452553, "count": 1, "min": 0.5737717915452553, "max": 0.5737717915452553}}}
# #metrics {"StartTime": 1770703881.8323593, "EndTime": 1770703881.8323672, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 0.7293018178539831, "count": 1, "min": 0.7293018178539831, "max": 0.7293018178539831}}}
# #metrics {"StartTime": 1770703881.8323991, "EndTime": 1770703881.8324072, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 0.5737297809619689, "count": 1, "min": 0.5737297809619689, "max": 0.5737297809619689}}}
# #metrics {"StartTime": 1770703881.832435, "EndTime": 1770703881.8324418, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 0.7279179149123065, "count": 1, "min": 0.7279179149123065, "max": 0.7279179149123065}}}
# #metrics {"StartTime": 1770703881.8324716, "EndTime": 1770703881.8324785, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 0.3342160271495823, "count": 1, "min": 0.3342160271495823, "max": 0.3342160271495823}}}
# #metrics {"StartTime": 1770703881.8325045, "EndTime": 1770703881.8325114, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 0.4005459373953139, "count": 1, "min": 0.4005459373953139, "max": 0.4005459373953139}}}
# #metrics {"StartTime": 1770703881.832543, "EndTime": 1770703881.832551, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 0.3348418289851044, "count": 1, "min": 0.3348418289851044, "max": 0.3348418289851044}}}
# #metrics {"StartTime": 1770703881.8325853, "EndTime": 1770703881.8325942, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 0.3996888111398472, "count": 1, "min": 0.3996888111398472, "max": 0.3996888111398472}}}
# #metrics {"StartTime": 1770703881.8326278, "EndTime": 1770703881.8326368, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 0.6697984252700476, "count": 1, "min": 0.6697984252700476, "max": 0.6697984252700476}}}
# #metrics {"StartTime": 1770703881.8326705, "EndTime": 1770703881.8326797, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 0.5997179692616146, "count": 1, "min": 0.5997179692616146, "max": 0.5997179692616146}}}
# #metrics {"StartTime": 1770703881.8327134, "EndTime": 1770703881.8327224, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 30}, "Metrics": {"validation_mse_objective": {"sum": 0.6680862502558385, "count": 1, "min": 0.6680862502558385, "max": 0.6680862502558385}}}
# #metrics {"StartTime": 1770703881.8327565, "EndTime": 1770703881.832765, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 31}, "Metrics": {"validation_mse_objective": {"sum": 0.5986515173466427, "count": 1, "min": 0.5986515173466427, "max": 0.5986515173466427}}}
# [02/10/2026 06:11:21 INFO 140012197074752] #quality_metric: host=algo-1, epoch=11, validation mse_objective <loss>=0.012454867145919864
# [02/10/2026 06:11:21 INFO 140012197074752] #early_stopping_criteria_metric: host=algo-1, epoch=11, criteria=mse_objective, value=0.01146976137502235
# [02/10/2026 06:11:21 INFO 140012197074752] Saving model for epoch: 11
# [02/10/2026 06:11:21 INFO 140012197074752] Saved checkpoint to "/tmp/tmp46v7zhnj/mx-mod-0000.params"
# [02/10/2026 06:11:21 INFO 140012197074752] Early stop condition met. Stopping training.
# [02/10/2026 06:11:21 INFO 140012197074752] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"StartTime": 1770703880.2231557, "EndTime": 1770703881.8405719, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 76852.0, "count": 1, "min": 76852, "max": 76852}, "Total Batches Seen": {"sum": 781.0, "count": 1, "min": 781, "max": 781}, "Max Records Seen Between Resets": {"sum": 5904.0, "count": 1, "min": 5904, "max": 5904}, "Max Batches Seen Between Resets": {"sum": 60.0, "count": 1, "min": 60, "max": 60}, "Reset Count": {"sum": 14.0, "count": 1, "min": 14, "max": 14}, "Number of Records Since Last Reset": {"sum": 5904.0, "count": 1, "min": 5904, "max": 5904}, "Number of Batches Since Last Reset": {"sum": 60.0, "count": 1, "min": 60, "max": 60}}}
# [02/10/2026 06:11:21 INFO 140012197074752] #throughput_metric: host=algo-1, train throughput=3649.9065849679655 records/second
# [02/10/2026 06:11:21 WARNING 140012197074752] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [02/10/2026 06:11:21 WARNING 140012197074752] wait_for_all_workers will not sync workers since the kv store is not running distributed
#
# 2026-02-10 06:11:28 Uploading - Uploading generated training model[02/10/2026 06:11:22 INFO 140012197074752] #early_stopping_criteria_metric: host=algo-1, epoch=11, criteria=mse_objective, value=0.01146976137502235
# [02/10/2026 06:11:22 INFO 140012197074752] #validation_score (algo-1) : ('mse_objective', 0.00999486296208005)
# [02/10/2026 06:11:22 INFO 140012197074752] #validation_score (algo-1) : ('mse', 0.00999486296208005)
# [02/10/2026 06:11:22 INFO 140012197074752] #validation_score (algo-1) : ('absolute_loss', 0.07585782911073224)
# [02/10/2026 06:11:22 INFO 140012197074752] #validation_score (algo-1) : ('rmse', 0.09997431151090788)
# [02/10/2026 06:11:22 INFO 140012197074752] #validation_score (algo-1) : ('r2', 0.9717857085677829)
# [02/10/2026 06:11:22 INFO 140012197074752] #validation_score (algo-1) : ('mae', 0.07585782911073224)
# [02/10/2026 06:11:22 INFO 140012197074752] #quality_metric: host=algo-1, validation mse_objective <loss>=0.00999486296208005
# [02/10/2026 06:11:22 INFO 140012197074752] #quality_metric: host=algo-1, validation mse <loss>=0.00999486296208005
# [02/10/2026 06:11:22 INFO 140012197074752] #quality_metric: host=algo-1, validation absolute_loss <loss>=0.07585782911073224
# [02/10/2026 06:11:22 INFO 140012197074752] #quality_metric: host=algo-1, validation rmse <loss>=0.09997431151090788
# [02/10/2026 06:11:22 INFO 140012197074752] #quality_metric: host=algo-1, validation r2 <loss>=0.9717857085677829
# [02/10/2026 06:11:22 INFO 140012197074752] #quality_metric: host=algo-1, validation mae <loss>=0.07585782911073224
# [02/10/2026 06:11:22 INFO 140012197074752] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 0.0001, "l1": 0.0, "lr_scheduler_step": 100, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 0.0001}
# [02/10/2026 06:11:22 INFO 140012197074752] Saved checkpoint to "/tmp/tmpihjau3ej/mx-mod-0000.params"
# [02/10/2026 06:11:22 INFO 140012197074752] Test data is not provided.
# #metrics {"StartTime": 1770703860.360859, "EndTime": 1770703882.6516647, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 491.396427154541, "count": 1, "min": 491.396427154541, "max": 491.396427154541}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 12.14146614074707, "count": 13, "min": 0.25463104248046875, "max": 1.8191337585449219}, "update.time": {"sum": 20940.080881118774, "count": 12, "min": 1606.1928272247314, "max": 2356.417655944824}, "finalize.time": {"sum": 805.8743476867676, "count": 1, "min": 805.8743476867676, "max": 805.8743476867676}, "setuptime": {"sum": 2.2351741790771484, "count": 1, "min": 2.2351741790771484, "max": 2.2351741790771484}, "totaltime": {"sum": 22394.827842712402, "count": 1, "min": 22394.827842712402, "max": 22394.827842712402}}}
#
# 2026-02-10 06:11:46 Completed - Training job completed
# Training seconds: 175
# Billable seconds: 175
# CPU times: user 794 ms, sys: 36.4 ms, total: 830 ms
# Wall time: 4min 18s

# %% [markdown]
# ### Setup Batch Transfomer Estimator

# %%
# %%time

linear_transformer = linear_estimator.transformer(1, "ml.m4.xlarge")

# start a transform job
input_location = "s3://{}/{}/batch/{}".format(
    bucket, prefix, batch_file
)  # use input data without ID column
linear_transformer.transform(input_location, content_type="text/csv", split_type="Line")
linear_transformer.wait()
# Out:
# INFO:sagemaker:Creating model with name: linear-learner-2026-02-10-06-16-23-156
# INFO:sagemaker:Creating transform job with name: linear-learner-2026-02-10-06-16-23-905
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /opt/conda/lib/python3.12/site-packages/IPython/core/magics/execution.py:1370 in time            │
# │                                                                                                  │
# │   1367 │   │   else:                                                                             │
# │   1368 │   │   │   st = clock2()                                                                 │
# │   1369 │   │   │   try:                                                                          │
# │ ❱ 1370 │   │   │   │   exec(code, glob, local_ns)                                                │
# │   1371 │   │   │   │   out = None                                                                │
# │   1372 │   │   │   │   # multi-line %%time case                                                  │
# │   1373 │   │   │   │   if expr_val is not None:                                                  │
# │ in <module>:7                                                                                    │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/workflow/pipeline_context.py:346 in wrapper    │
# │                                                                                                  │
# │   343 │   │   │                                                                                  │
# │   344 │   │   │   return _StepArguments(retrieve_caller_name(self_instance), run_func, *args,    │
# │   345 │   │                                                                                      │
# │ ❱ 346 │   │   return run_func(*args, **kwargs)                                                   │
# │   347 │                                                                                          │
# │   348 │   return wrapper                                                                         │
# │   349                                                                                            │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/transformer.py:302 in transform                │
# │                                                                                                  │
# │   299 │   │   │   sagemaker_session=self.sagemaker_session,                                      │
# │   300 │   │   )                                                                                  │
# │   301 │   │                                                                                      │
# │ ❱ 302 │   │   self.latest_transform_job = _TransformJob.start_new(                               │
# │   303 │   │   │   self,                                                                          │
# │   304 │   │   │   data,                                                                          │
# │   305 │   │   │   data_type,                                                                     │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/transformer.py:636 in start_new                │
# │                                                                                                  │
# │   633 │   │   │   batch_data_capture_config,                                                     │
# │   634 │   │   )                                                                                  │
# │   635 │   │                                                                                      │
# │ ❱ 636 │   │   transformer.sagemaker_session.transform(**transform_args)                          │
# │   637 │   │                                                                                      │
# │   638 │   │   return cls(transformer.sagemaker_session, transformer._current_job_name)           │
# │   639                                                                                            │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/session.py:3966 in transform                   │
# │                                                                                                  │
# │   3963 │   │   │   logger.debug("Transform request: %s", json.dumps(request, indent=4))          │
# │   3964 │   │   │   self.sagemaker_client.create_transform_job(**request)                         │
# │   3965 │   │                                                                                     │
# │ ❱ 3966 │   │   self._intercept_create_request(transform_request, submit, self.transform.__name_  │
# │   3967 │                                                                                         │
# │   3968 │   def _create_model_request(                                                            │
# │   3969 │   │   self,                                                                             │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/session.py:6819 in _intercept_create_request   │
# │                                                                                                  │
# │   6816 │   │   │   create (functor): a functor calls the sagemaker client create method          │
# │   6817 │   │   │   func_name (str): the name of the function needed intercepting                 │
# │   6818 │   │   """                                                                               │
# │ ❱ 6819 │   │   return create(request)                                                            │
# │   6820 │                                                                                         │
# │   6821 │   def _create_inference_recommendations_job_request(                                    │
# │   6822 │   │   self,                                                                             │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/session.py:3964 in submit                      │
# │                                                                                                  │
# │   3961 │   │   def submit(request):                                                              │
# │   3962 │   │   │   logger.info("Creating transform job with name: %s", job_name)                 │
# │   3963 │   │   │   logger.debug("Transform request: %s", json.dumps(request, indent=4))          │
# │ ❱ 3964 │   │   │   self.sagemaker_client.create_transform_job(**request)                         │
# │   3965 │   │                                                                                     │
# │   3966 │   │   self._intercept_create_request(transform_request, submit, self.transform.__name_  │
# │   3967                                                                                           │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/botocore/client.py:569 in _api_call                      │
# │                                                                                                  │
# │    566 │   │   │   │   │   f"{py_operation_name}() only accepts keyword arguments."              │
# │    567 │   │   │   │   )                                                                         │
# │    568 │   │   │   # The "self" in this scope is referring to the BaseClient.                    │
# │ ❱  569 │   │   │   return self._make_api_call(operation_name, kwargs)                            │
# │    570 │   │                                                                                     │
# │    571 │   │   _api_call.__name__ = str(py_operation_name)                                       │
# │    572                                                                                           │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/botocore/client.py:1023 in _make_api_call                │
# │                                                                                                  │
# │   1020 │   │   │   │   "Code"                                                                    │
# │   1021 │   │   │   )                                                                             │
# │   1022 │   │   │   error_class = self.exceptions.from_code(error_code)                           │
# │ ❱ 1023 │   │   │   raise error_class(parsed_response, operation_name)                            │
# │   1024 │   │   else:                                                                             │
# │   1025 │   │   │   return parsed_response                                                        │
# │   1026                                                                                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ClientError: An error occurred (AccessDeniedException) when calling the CreateTransformJob operation: User:
# arn:aws:sts::472407119167:assumed-role/LabRole/SageMaker is not authorized to perform: sagemaker:CreateTransformJob
# on resource: arn:aws:sagemaker:us-east-1:472407119167:transform-job/linear-learner-2026-02-10-06-16-23-905 with an
# explicit deny in an identity-based policy:
# arn:aws:iam::472407119167:policy/c193294a4969078l13462228t1w472407119167-VocLabPolicy3-Zgdr0OwtuU1a
# (c193294a4969078l13462228t1w472407119167-VocLabPolicy3-Zgdr0OwtuU1a)

# %%
# Since the Linear Transformer inference can't be done due to permissions, we'll try an alternative using SageMaker Processing
from sagemaker.processing import ScriptProcessor, ProcessingInput, ProcessingOutput
from sagemaker import get_execution_role
import os
import numpy as np
import json
#from sagemaker_inference import model_server
import argparse

# 1. Define the processing container for Linear Learner inference
script_processor = ScriptProcessor(
    image_uri=linear_estimator.image_uri,   # same container used for training
    command=["python3"],
    role=role,
    instance_count=1,
    instance_type="ml.m5.large"
)

# %%
# 2. Create a Python script that performs inference
inference_script=""
with open("inference.py", "w") as f:
    f.write(inference_script)



def model_fn(model_dir):
    # Load the Linear Learner model
    import pickle
    with open(os.path.join(model_dir, "model_algo-1"), "rb") as f:
        return pickle.load(f)

def input_fn(input_data, content_type):
    return pd.read_csv(input_data, header=None)

def predict_fn(data, model):
    return model.predict(data)

def output_fn(prediction, accept):
    return "\n".join([str(p) for p in prediction])

# %%
# 3. Run the processing job
script_processor.run(
    code="inference.py",
    inputs=[
        ProcessingInput(
            source=f"s3://{bucket}/{prefix}/batch/{batch_file}",
            destination="/opt/ml/processing/input"
        ),
        ProcessingInput(
            source=linear_estimator.model_data,
            destination="/opt/ml/processing/model"
        )
    ],
    outputs=[
        ProcessingOutput(
            output_name="predictions",
            source="/opt/ml/processing/output",
            destination=f"s3://{bucket}/{prefix}/predictions/"
        )
    ]
)
# Out:
# INFO:sagemaker:Creating processing-job with name linear-learner-2026-02-10-06-35-59-456
# ERROR:sagemaker:Please check the troubleshooting guide for common errors: https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-python-sdk-troubleshooting.html#sagemaker-python-sdk-troubleshooting-create-processing-job
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:2                                                                                    │
# │                                                                                                  │
# │    1 # 3. Run the processing job                                                                 │
# │ ❱  2 script_processor.run(                                                                       │
# │    3 │   code="inference.py",                                                                    │
# │    4 │   inputs=[                                                                                │
# │    5 │   │   ProcessingInput(                                                                    │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/workflow/pipeline_context.py:346 in wrapper    │
# │                                                                                                  │
# │   343 │   │   │                                                                                  │
# │   344 │   │   │   return _StepArguments(retrieve_caller_name(self_instance), run_func, *args,    │
# │   345 │   │                                                                                      │
# │ ❱ 346 │   │   return run_func(*args, **kwargs)                                                   │
# │   347 │                                                                                          │
# │   348 │   return wrapper                                                                         │
# │   349                                                                                            │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/processing.py:680 in run                       │
# │                                                                                                  │
# │    677 │   │   )                                                                                 │
# │    678 │   │                                                                                     │
# │    679 │   │   experiment_config = check_and_get_run_experiment_config(experiment_config)        │
# │ ❱  680 │   │   self.latest_job = ProcessingJob.start_new(                                        │
# │    681 │   │   │   processor=self,                                                               │
# │    682 │   │   │   inputs=normalized_inputs,                                                     │
# │    683 │   │   │   outputs=normalized_outputs,                                                   │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/processing.py:916 in start_new                 │
# │                                                                                                  │
# │    913 │   │   logger.debug("Outputs: %s", process_args["output_config"]["Outputs"])             │
# │    914 │   │                                                                                     │
# │    915 │   │   # Call sagemaker_session.process using the arguments dictionary.                  │
# │ ❱  916 │   │   processor.sagemaker_session.process(**process_args)                               │
# │    917 │   │                                                                                     │
# │    918 │   │   return cls(                                                                       │
# │    919 │   │   │   processor.sagemaker_session,                                                  │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/session.py:1600 in process                     │
# │                                                                                                  │
# │   1597 │   │   │   │   )                                                                         │
# │   1598 │   │   │   │   raise e                                                                   │
# │   1599 │   │                                                                                     │
# │ ❱ 1600 │   │   self._intercept_create_request(process_request, submit, self.process.__name__)    │
# │   1601 │                                                                                         │
# │   1602 │   def _get_process_request(                                                             │
# │   1603 │   │   self,                                                                             │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/session.py:6819 in _intercept_create_request   │
# │                                                                                                  │
# │   6816 │   │   │   create (functor): a functor calls the sagemaker client create method          │
# │   6817 │   │   │   func_name (str): the name of the function needed intercepting                 │
# │   6818 │   │   """                                                                               │
# │ ❱ 6819 │   │   return create(request)                                                            │
# │   6820 │                                                                                         │
# │   6821 │   def _create_inference_recommendations_job_request(                                    │
# │   6822 │   │   self,                                                                             │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/session.py:1598 in submit                      │
# │                                                                                                  │
# │   1595 │   │   │   │   logger.error(                                                             │
# │   1596 │   │   │   │   │   "Please check the troubleshooting guide for common errors: %s", trou  │
# │   1597 │   │   │   │   )                                                                         │
# │ ❱ 1598 │   │   │   │   raise e                                                                   │
# │   1599 │   │                                                                                     │
# │   1600 │   │   self._intercept_create_request(process_request, submit, self.process.__name__)    │
# │   1601                                                                                           │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/session.py:1588 in submit                      │
# │                                                                                                  │
# │   1585 │   │   │   try:                                                                          │
# │   1586 │   │   │   │   logger.info("Creating processing-job with name %s", job_name)             │
# │   1587 │   │   │   │   logger.debug("process request: %s", json.dumps(request, indent=4))        │
# │ ❱ 1588 │   │   │   │   self.sagemaker_client.create_processing_job(**request)                    │
# │   1589 │   │   │   except Exception as e:                                                        │
# │   1590 │   │   │   │   troubleshooting = (                                                       │
# │   1591 │   │   │   │   │   "https://docs.aws.amazon.com/sagemaker/latest/dg/"                    │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/botocore/client.py:569 in _api_call                      │
# │                                                                                                  │
# │    566 │   │   │   │   │   f"{py_operation_name}() only accepts keyword arguments."              │
# │    567 │   │   │   │   )                                                                         │
# │    568 │   │   │   # The "self" in this scope is referring to the BaseClient.                    │
# │ ❱  569 │   │   │   return self._make_api_call(operation_name, kwargs)                            │
# │    570 │   │                                                                                     │
# │    571 │   │   _api_call.__name__ = str(py_operation_name)                                       │
# │    572                                                                                           │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/botocore/client.py:1023 in _make_api_call                │
# │                                                                                                  │
# │   1020 │   │   │   │   "Code"                                                                    │
# │   1021 │   │   │   )                                                                             │
# │   1022 │   │   │   error_class = self.exceptions.from_code(error_code)                           │
# │ ❱ 1023 │   │   │   raise error_class(parsed_response, operation_name)                            │
# │   1024 │   │   else:                                                                             │
# │   1025 │   │   │   return parsed_response                                                        │
# │   1026                                                                                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ClientError: An error occurred (ValidationException) when calling the CreateProcessingJob operation: No S3 objects
# found under S3 URL "s3://usdmsaai540-spring2026-team1/CCPP-enery-prediction-linear-regression/batch/batch_data.csv"
# given in input data source. Please ensure that the bucket exists in the selected region (us-east-1), that objects
# exist under that S3 prefix, and that the role "arn:aws:iam::472407119167:role/LabRole" has "s3:ListBucket"
# permissions on bucket "usdmsaai540-spring2026-team1".

# %% [markdown]
# ### Plot the Batch Transform Result Compare to Ground Truth

# %%
import re


def get_csv_output_from_s3(s3uri, batch_file):
    file_name = "{}.out".format(batch_file)
    match = re.match("s3://([^/]+)/(.*)", "{}/{}".format(s3uri, file_name))
    output_bucket, output_prefix = match.group(1), match.group(2)
    s3.download_file(output_bucket, output_prefix, file_name)
    return pd.read_csv(file_name, sep=",", header=None)

# %%
s3 = boto3.client("s3")

# %%
output_df = get_csv_output_from_s3(linear_transformer.output_path, batch_file)
output_df.head(8)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 output_df = get_csv_output_from_s3(sm_transformer.output_path, batch_file)                   │
# │   2 output_df.head(8)                                                                            │
# │   3                                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# NameError: name 'sm_transformer' is not defined

# %%
output_df
# Out:
#             0
# 0    0.168284
# 1    0.168284
# 2    0.168284
# 3    0.168284
# 4    0.168284
# ..        ...
# 644  0.262286
# 645  0.262286
# 646  0.262286
# 647  0.262286
# 648  0.168284
#
# [649 rows x 1 columns]

# %%
compare_df = data_test[['gt_energy_yield']]

# %%
compare_df

# %%
combined_df = pd.concat([compare_df, output_df], axis=1)

# %%
combined_df

# %%
combined_df.rename(columns={0: 'Predited Energy'}, inplace=True)

# %%
combined_df

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))

# Plotting the first column with a solid line
plt.plot(combined_df.index, combined_df['kwh'], linestyle='-', color='blue', label='Column 1 - Solid')

# Plotting the second column with a dotted line
plt.plot(combined_df.index, combined_df['Predited Energy'], linestyle=':', color='red', label='Column 2 - Dotted')
plt.legend()
# Show plot
plt.show()

# %%
# %%html
#
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>
# Out:
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>
