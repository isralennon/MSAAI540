# %% [markdown]
# ## 2. Data Exploration on the Combined Data Set and Process

# %%
#import libraries
import boto3
import sagemaker
import pandas as pd
import os
import tqdm
import numpy as np

sess = sagemaker.Session()
bucket = sess.default_bucket()
role = sagemaker.get_execution_role()
region = boto3.Session().region_name
account_id = boto3.client("sts").get_caller_identity().get("Account")

sm = boto3.Session().client(service_name="sagemaker", region_name=region)

# %%
s3_private_path_csv = "s3://{}/CCPP/data/processeddata".format(bucket)
print(s3_private_path_csv)
# Out:
# s3://sagemaker-us-east-1-483525480215/CCPP/data/processeddata

# %% [markdown]
# ### EDA:

# %%
gt_all_years = pd.read_csv(f'{s3_private_path_csv}/gas_turbine.csv')

# %%
gt_all_years.head()
# Out:
#                     DT      AT      AP      AH    AFDP    GTEP     TIT  \
# 0  2011-01-01T00:00:00  4.5878  1018.7  83.675  3.5758  23.979  1086.2
# 1  2011-01-01T01:00:00  4.2932  1018.3  84.235  3.5709  23.951  1086.1
# 2  2011-01-01T02:00:00  3.9045  1018.4  84.858  3.5828  23.990  1086.5
# 3  2011-01-01T03:00:00  3.7436  1018.3  85.434  3.5808  23.911  1086.5
# 4  2011-01-01T04:00:00  3.7516  1017.8  85.182  3.5781  23.917  1085.9
#
#       TAT     TEY     CDP       CO     NOX
# 0  549.83  134.67  11.898  0.32663  81.952
# 1  550.05  134.67  11.892  0.44784  82.377
# 2  550.19  135.10  12.042  0.45144  83.776
# 3  550.17  135.03  11.990  0.23107  82.505
# 4  550.00  134.67  11.910  0.26747  82.028

# %%
s3_private_uci_data_path_csv = "s3://{}/CCPP/data/uci_dataset".format(bucket)
print(s3_private_uci_data_path_csv)
# Out:
# s3://sagemaker-us-east-1-483525480215/CCPP/data/uci_dataset

# %%
#load weather infomation
weather_hourly_turkey = pd.read_csv(os.path.join(s3_private_uci_data_path_csv,'CCPP 2011-2015 Full Weather Data.csv'))
weather_hourly_turkey.head()
# Out:
#                        name             datetime  temp  feelslike  dew  \
# 0  Marmara Ereglisi, Turkey  2011-01-01T00:00:00  -2.3       -2.3 -4.7
# 1  Marmara Ereglisi, Turkey  2011-01-01T01:00:00  -1.6       -1.6 -4.7
# 2  Marmara Ereglisi, Turkey  2011-01-01T02:00:00  -2.4       -2.4 -4.7
# 3  Marmara Ereglisi, Turkey  2011-01-01T03:00:00   0.1       -1.8 -4.6
# 4  Marmara Ereglisi, Turkey  2011-01-01T04:00:00  -0.8       -2.6 -3.0
#
#    humidity  precip  precipprob preciptype  snow  ...  sealevelpressure  \
# 0     83.98     0.0           0        NaN   0.0  ...            1022.2
# 1     79.28     0.0           0        NaN   0.0  ...            1021.4
# 2     84.56     0.0           0        NaN   0.0  ...            1021.3
# 3     70.66     0.0           0        NaN   0.0  ...            1021.3
# 4     84.94     0.0           0        NaN   0.0  ...            1021.2
#
#    cloudcover  visibility  solarradiation  solarenergy  uvindex  severerisk  \
# 0         0.0        12.0             NaN          NaN      NaN         NaN
# 1         0.0        12.0             NaN          NaN      NaN         NaN
# 2         0.0        11.9             NaN          NaN      NaN         NaN
# 3         0.0        11.9             NaN          NaN      NaN         NaN
# 4         0.0         9.4             NaN          NaN      NaN         NaN
#
#    conditions         icon                                           stations
# 0       Clear  clear-night  17056099999,LTBU,17054099999,17115099999,17060...
# 1       Clear  clear-night  17056099999,LTBU,17054099999,17115099999,17060...
# 2       Clear  clear-night  17056099999,LTBU,17054099999,17115099999,17060...
# 3       Clear  clear-night  17056099999,LTBU,17054099999,17115099999,17060...
# 4       Clear  clear-night  17056099999,LTBU,17054099999,17115099999,17060...
#
# [5 rows x 24 columns]

# %%
weather_hourly_turkey['name'].nunique()
# Out:
# 1

# %% [markdown]
# # Combine weather_data dataframe to gt_all_years when datetimes match

# %%
# Convert datetime columns
gt_all_years['DT'] = pd.to_datetime(gt_all_years['DT'])
weather_hourly_turkey['datetime'] = pd.to_datetime(weather_hourly_turkey['datetime'])

# Automatically select all columns except 'datetime' and 'name'
cols_to_add = [col for col in weather_hourly_turkey.columns if col not in ['datetime', 'name']]

# Merge on datetime
gt_merged = gt_all_years.merge(
    weather_hourly_turkey[['datetime'] + cols_to_add],
    left_on='DT',
    right_on='datetime',
    how='left'
).drop(columns=['datetime'])

gt_merged.head()
# Out:
#                    DT      AT      AP      AH    AFDP    GTEP     TIT     TAT  \
# 0 2011-01-01 00:00:00  4.5878  1018.7  83.675  3.5758  23.979  1086.2  549.83
# 1 2011-01-01 01:00:00  4.2932  1018.3  84.235  3.5709  23.951  1086.1  550.05
# 2 2011-01-01 02:00:00  3.9045  1018.4  84.858  3.5828  23.990  1086.5  550.19
# 3 2011-01-01 03:00:00  3.7436  1018.3  85.434  3.5808  23.911  1086.5  550.17
# 4 2011-01-01 04:00:00  3.7516  1017.8  85.182  3.5781  23.917  1085.9  550.00
#
#       TEY     CDP  ...  sealevelpressure  cloudcover  visibility  \
# 0  134.67  11.898  ...            1022.2         0.0        12.0
# 1  134.67  11.892  ...            1021.4         0.0        12.0
# 2  135.10  12.042  ...            1021.3         0.0        11.9
# 3  135.03  11.990  ...            1021.3         0.0        11.9
# 4  134.67  11.910  ...            1021.2         0.0         9.4
#
#    solarradiation  solarenergy  uvindex  severerisk  conditions         icon  \
# 0             NaN          NaN      NaN         NaN       Clear  clear-night
# 1             NaN          NaN      NaN         NaN       Clear  clear-night
# 2             NaN          NaN      NaN         NaN       Clear  clear-night
# 3             NaN          NaN      NaN         NaN       Clear  clear-night
# 4             NaN          NaN      NaN         NaN       Clear  clear-night
#
#                                             stations
# 0  17056099999,LTBU,17054099999,17115099999,17060...
# 1  17056099999,LTBU,17054099999,17115099999,17060...
# 2  17056099999,LTBU,17054099999,17115099999,17060...
# 3  17056099999,LTBU,17054099999,17115099999,17060...
# 4  17056099999,LTBU,17054099999,17115099999,17060...
#
# [5 rows x 34 columns]

# %%
gt_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36737 entries, 0 to 36736
# Data columns (total 34 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   DT                36737 non-null  datetime64[ns]
#  1   AT                36737 non-null  float64
#  2   AP                36737 non-null  float64
#  3   AH                36737 non-null  float64
#  4   AFDP              36737 non-null  float64
#  5   GTEP              36737 non-null  float64
#  6   TIT               36737 non-null  float64
#  7   TAT               36737 non-null  float64
#  8   TEY               36737 non-null  float64
#  9   CDP               36737 non-null  float64
#  10  CO                36737 non-null  float64
#  11  NOX               36737 non-null  float64
#  12  temp              36734 non-null  float64
#  13  feelslike         36734 non-null  float64
#  14  dew               36734 non-null  float64
#  15  humidity          36734 non-null  float64
#  16  precip            36734 non-null  float64
#  17  precipprob        36734 non-null  float64
#  18  preciptype        1131 non-null   object
#  19  snow              36734 non-null  float64
#  20  snowdepth         36734 non-null  float64
#  21  windgust          20533 non-null  float64
#  22  windspeed         36734 non-null  float64
#  23  winddir           36734 non-null  float64
#  24  sealevelpressure  36734 non-null  float64
#  25  cloudcover        36726 non-null  float64
#  26  visibility        36101 non-null  float64
#  27  solarradiation    14768 non-null  float64
#  28  solarenergy       14768 non-null  float64
#  29  uvindex           14768 non-null  float64
#  30  severerisk        0 non-null      float64
#  31  conditions        36734 non-null  object
#  32  icon              36734 non-null  object
#  33  stations          36734 non-null  object
# dtypes: datetime64[ns](1), float64(29), object(4)
# memory usage: 9.5+ MB

# %%
#load  turkish holidays
turkish_holidays = pd.read_csv(os.path.join(s3_private_uci_data_path_csv,"TurkishHolidays.tsv"), sep='\t', encoding='latin1')
turkish_holidays.head()
# Out:
#         Date  DayOfWeek                                            Name  \
# 0   1/1/2000   Saturday                                  New Year's Day
# 1  3/20/2000     Monday                                   March Equinox
# 2  4/23/2000     Sunday         National Sovereignty and Children's Day
# 3  5/19/2000     Friday  Commemoration of Atatürk, Youth and Sports Day
# 4  6/21/2000  Wednesday                                   June Solstice
#
#                Type
# 0  National Holiday
# 1            Season
# 2  National Holiday
# 3  National Holiday
# 4            Season

# %%
turkish_holidays.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 642 entries, 0 to 641
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       642 non-null    object
#  1   DayOfWeek  642 non-null    object
#  2   Name       642 non-null    object
#  3   Type       642 non-null    object
# dtypes: object(4)
# memory usage: 20.2+ KB

# %% [markdown]
# # Combine turkish_holidays with prefix "holiday_" and gt_merged by date

# %%
# Convert Turkish holidays Date to datetime.date
turkish_holidays['Date'] = pd.to_datetime(turkish_holidays['Date']).dt.date

# Prefix all holiday columns except 'Date'
holiday_cols = [col for col in turkish_holidays.columns if col != 'Date']
turkish_holidays_prefixed = turkish_holidays.rename(columns={col: f"holiday_{col}" for col in holiday_cols})

# Convert gt_merged DT to datetime.date for merging
gt_merged['DT_date'] = gt_merged['DT'].dt.date

# Merge datasets on date
gt_merged_holidays = gt_merged.merge(
    turkish_holidays_prefixed,
    left_on='DT_date',
    right_on='Date',
    how='left'
)

# Drop the temporary DT_date and duplicate Date column
gt_merged_holidays = gt_merged_holidays.drop(columns=['DT_date', 'Date'])

#  32  icon               36734 non-null  object
#  33  stations           36734 non-null  object
#  34  holiday_DayOfWeek  2262 non-null   object
#  35  holiday_Name       2262 non-null   object
#  36  holiday_Type       2262 non-null   object
# dtypes: datetime64[ns](1), float64(29), object(7)
# memory usage: 10.4+ MB

# %%
# Check NaN
gt_merged_holidays.isna().sum()
# Out:
# DT                       0
# AT                       0
# AP                       0
# AH                       0
# AFDP                     0
# GTEP                     0
# TIT                      0
# TAT                      0
# TEY                      0
# CDP                      0
# CO                       0
# NOX                      0
# temp                     3
# feelslike                3
# dew                      3
# humidity                 3
# precip                   3
# precipprob               3
# preciptype           35606
# snow                     3
# snowdepth                3
# windgust             16204
# windspeed                3
# winddir                  3
# sealevelpressure         3
# cloudcover              11
# visibility             636
# solarradiation       21969
# solarenergy          21969
# uvindex              21969
# severerisk           36737
# conditions               3
# icon                     3
# stations                 3
# holiday_DayOfWeek    34475
# holiday_Name         34475
# holiday_Type         34475
# dtype: int64

# %% [markdown]
# ### Feature Engineering:

# %%
# holiday type
print("Type of data:", gt_merged_holidays['holiday_Type'].dtype  )
print(gt_merged_holidays['holiday_Type'].unique())
print(gt_merged_holidays['holiday_Type'].value_counts())
# Out:
# Type of data: object
# ['National Holiday' nan 'Season' 'Half Day' 'Observance'
#  'Holiday for Public Servants']
# holiday_Type
# National Holiday               1337
# Season                          384
# Half Day                        349
# Observance                      144
# Holiday for Public Servants      48
# Name: count, dtype: int64

# %%
numberic_cols = gt_merged_holidays.select_dtypes(include=['number']).columns
numberic_cols
# Out:
# Index(['AT', 'AP', 'AH', 'AFDP', 'GTEP', 'TIT', 'TAT', 'TEY', 'CDP', 'CO',
#        'NOX', 'temp', 'feelslike', 'dew', 'humidity', 'precip', 'precipprob',
#        'snow', 'snowdepth', 'windgust', 'windspeed', 'winddir',
#        'sealevelpressure', 'cloudcover', 'visibility', 'solarradiation',
#        'solarenergy', 'uvindex', 'severerisk'],
#       dtype='object')

# %%
categorical_cols = gt_merged_holidays.select_dtypes(include=['object']).columns
categorical_cols
# Out:
# Index(['preciptype', 'conditions', 'icon', 'stations', 'holiday_DayOfWeek',
#        'holiday_Name', 'holiday_Type'],
#       dtype='object')

# %%
# Correlation matrix
correlation_matrix = gt_merged_holidays[numberic_cols].corr()
correlation_matrix
# Out:
#                         AT        AP        AH      AFDP      GTEP       TIT  \
# AT                1.000000 -0.406618 -0.476311  0.252006  0.045882  0.183703
# AP               -0.406618  1.000000 -0.015107 -0.040379  0.057506 -0.005378
# AH               -0.476311 -0.015107  1.000000 -0.147868 -0.235167 -0.221786
# AFDP              0.252006 -0.040379 -0.147868  1.000000  0.678466  0.691247
# GTEP              0.045882  0.057506 -0.235167  0.678466  1.000000  0.874233
# TIT               0.183703 -0.005378 -0.221786  0.691247  0.874233  1.000000
# TAT               0.281822 -0.225556  0.023005 -0.466897 -0.699697 -0.380851
# TEY              -0.091129  0.118208 -0.137362  0.665446  0.964125  0.910301
# NOX                -0.126797       -0.202973    -0.202851 -0.203312
# temp                0.284163        0.525047     0.524702  0.524350
# feelslike           0.279563        0.504565     0.504221  0.503947
# dew                 0.162538        0.219362     0.218912  0.219785
# humidity           -0.342934       -0.709114    -0.709141 -0.706879
# precip             -0.046442       -0.019325    -0.019650 -0.018982
# precipprob         -0.079707       -0.038979    -0.039389 -0.039752
# snow               -0.022104       -0.009848    -0.010261 -0.010212
# snowdepth          -0.038360       -0.028000    -0.028147 -0.027742
# windgust           -0.007914        0.014557     0.014894  0.014860
# windspeed           0.001034        0.216736     0.216974  0.216579
# winddir            -0.093898       -0.162024    -0.162145 -0.162484
# sealevelpressure   -0.044871       -0.114104    -0.113866 -0.114198
# cloudcover         -0.345055       -0.018899    -0.018919 -0.018663
# visibility          1.000000        0.138127     0.138172  0.137710
# solarradiation      0.138127        1.000000     0.999735  0.996792
# solarenergy         0.138172        0.999735     1.000000  0.996504
# uvindex             0.137710        0.996792     0.996504  1.000000
# severerisk               NaN             NaN          NaN       NaN
#
#                   severerisk
# AT                       NaN
# AP                       NaN
# AH                       NaN
# AFDP                     NaN
# GTEP                     NaN
# TIT                      NaN
# TAT                      NaN
# TEY                      NaN
# CDP                      NaN
# CO                       NaN
# NOX                      NaN
# temp                     NaN
# feelslike                NaN
# dew                      NaN
# humidity                 NaN
# precip                   NaN
# precipprob               NaN
# snow                     NaN
# snowdepth                NaN
# windgust                 NaN
# windspeed                NaN
# winddir                  NaN
# sealevelpressure         NaN
# cloudcover               NaN
# visibility               NaN
# solarradiation           NaN
# solarenergy              NaN
# uvindex                  NaN
# severerisk               NaN
#
# [29 rows x 29 columns]

# %%
# Visualize correlation matrix using seaborn heatmap
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(14, 14))
sns.heatmap(correlation_matrix, annot=True, fmt=".1f", cmap='coolwarm')
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
# Top correlated features with target variable 'TEY'
target_variable = 'TEY'
correlation_with_target = correlation_matrix[target_variable].sort_values(ascending=False)
correlation_with_target = correlation_with_target.drop(target_variable)  # Remove self-correlation
# Top 10 features
correlation_with_target.head(10)
# Out:
# CDP                 0.988778
# GTEP                0.964125
# TIT                 0.910301
# AFDP                0.665446
# solarradiation      0.151543
# solarenergy         0.151181
# uvindex             0.151021
# AP                  0.118208
# cloudcover          0.112492
# sealevelpressure    0.060976
# Name: TEY, dtype: float64

# %%
# Top correlated features with target variable 'CO'
target_variable = 'CO'
correlation_with_target = correlation_matrix[target_variable].sort_values(ascending=False)
correlation_with_target = correlation_with_target.drop(target_variable)  # Remove self-correlation
# Top 10 features
correlation_with_target.head(10)
# Out:
# NOX                 0.340609
# AH                  0.106558
# humidity            0.091598
# AP                  0.067024
# TAT                 0.058346
# windgust            0.047771
# sealevelpressure    0.039157
# winddir             0.037385
# visibility          0.034225
# snowdepth           0.010988
# Name: CO, dtype: float64

# %%
# Top correlated features with target variable 'NOX'
target_variable = 'NOX'
correlation_with_target = correlation_matrix[target_variable].sort_values(ascending=False)
correlation_with_target = correlation_with_target.drop(target_variable)  # Remove self-correlation
# Top 10 features
correlation_with_target.head(10)
# Out:
# CO                  0.340609
# humidity            0.210353
# AP                  0.191954
# cloudcover          0.182037
# AH                  0.164631
# sealevelpressure    0.163341
# winddir             0.085867
# precipprob          0.040641
# snowdepth           0.026210
# precip              0.012225
# Name: NOX, dtype: float64

# %%
# Feature Correlation matrix within 10 most correlated features for 'TEY'
target_variable = 'TEY'
correlation_with_target = correlation_matrix[target_variable].sort_values(ascending=False)
correlation_with_target = correlation_with_target.drop(target_variable)  # Remove self-correlation
# Top 10 features
correlation_with_target.head(10)
top_10_features = correlation_with_target.head(10).index.tolist()
correlation_matrix_top_10 = correlation_matrix.loc[top_10_features, top_10_features]
correlation_matrix_top_10
# Out:
#                        CDP      GTEP       TIT      AFDP  solarradiation  \
# CDP               1.000000  0.978470  0.908471  0.702536        0.189776
# GTEP              0.978470  1.000000  0.874233  0.678466        0.233091
# TIT               0.908471  0.874233  1.000000  0.691247        0.242747
# AFDP              0.702536  0.678466  0.691247  1.000000        0.243995
# solarradiation    0.189776  0.233091  0.242747  0.243995        1.000000
# solarenergy       0.189376  0.232639  0.242267  0.243605        0.999735
# uvindex           0.189218  0.232371  0.242019  0.243445        0.996792
# AP                0.102613  0.057506 -0.005378 -0.040379       -0.164053
# cloudcover        0.079456  0.072804  0.022576 -0.012789       -0.018899
# sealevelpressure  0.035582  0.020673 -0.033219 -0.063079       -0.114104
#
#                   solarenergy   uvindex        AP  cloudcover  \
# CDP                  0.189376  0.189218  0.102613    0.079456
# GTEP                 0.232639  0.232371  0.057506    0.072804
# TIT                  0.242267  0.242019 -0.005378    0.022576
# AFDP                 0.243605  0.243445 -0.040379   -0.012789
# solarradiation       0.999735  0.996792 -0.164053   -0.018899
# solarenergy          1.000000  0.996504 -0.163764   -0.018919
# uvindex              0.996504  1.000000 -0.164169   -0.018663
# AP                  -0.163764 -0.164169  1.000000    0.106651
# cloudcover          -0.018919 -0.018663  0.106651    1.000000
# sealevelpressure    -0.113866 -0.114198  0.331977   -0.067174
#
#                   sealevelpressure
# CDP                       0.035582
# GTEP                      0.020673
# TIT                      -0.033219
# AFDP                     -0.063079
# solarradiation           -0.114104
# solarenergy              -0.113866
# uvindex                  -0.114198
# AP                        0.331977
# cloudcover               -0.067174
# sealevelpressure          1.000000

# %%
data_set_filtered = gt_merged_holidays[top_10_features].copy()
data_set_filtered['Target'] = gt_merged_holidays['TEY']

# %%
data_set_filtered.dropna(inplace=True)
feature_set_filtered=data_set_filtered.drop(columns=['Target'])
target_variable=data_set_filtered['Target']

# %%
# Variance Inflation Factor (VIF) Calculation
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_data = pd.DataFrame()
vif_data["feature"] = top_10_features
vif_data["VIF"] = [variance_inflation_factor(feature_set_filtered[top_10_features].values, i) for i in range(len(top_10_features))]
vif_data
# Out:
#             feature           VIF
# 0               CDP   2599.106985
# 1              GTEP    552.765152
# 2               TIT  18714.230417
# 3              AFDP    102.213900
# 4    solarradiation   3183.187735
# 5       solarenergy   2917.171186
# 6           uvindex    240.168407
# 7                AP  23487.153026
# 8        cloudcover      3.054201
# 9  sealevelpressure  25876.037282

# %%
high_vif_features = vif_data[vif_data["VIF"] > 1000]["feature"].tolist()
feature_set_filtered.drop(columns=high_vif_features, inplace=True)

# %%
vif_data = pd.DataFrame()
vif_data["feature"] = feature_set_filtered.columns
vif_data["VIF"] = [variance_inflation_factor(feature_set_filtered.values, i) for i in range(len(feature_set_filtered.columns))]
vif_data
# Out:
#       feature        VIF
# 0        GTEP  74.654025
# 1        AFDP  70.592474
# 2     uvindex   1.616495
# 3  cloudcover   2.783055

# %%
from io import StringIO
csv_buffer = StringIO()
data_set_filtered.to_csv(csv_buffer,index=False)
s3 = boto3.client('s3')
s3.put_object(
    Bucket=bucket,
    Key="CCPP/data/feature_set/clean_data.csv",
    Body=csv_buffer.getvalue()
)
# Out:
# {'ResponseMetadata': {'RequestId': 'BM59W2A02PKW9J2K',
#   'HostId': 'KeChsELWCo8YOhSdnM717V+5DbCxPM06/KVwkECuSLvYbIA/rdvk5xtVobYDu0U9tq+tsB9XGGLsCPTER6KKT2HXnCpurbHm',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'KeChsELWCo8YOhSdnM717V+5DbCxPM06/KVwkECuSLvYbIA/rdvk5xtVobYDu0U9tq+tsB9XGGLsCPTER6KKT2HXnCpurbHm',
#    'x-amz-request-id': 'BM59W2A02PKW9J2K',
#    'date': 'Wed, 04 Feb 2026 06:15:05 GMT',
#    'x-amz-server-side-encryption': 'AES256',
#    'etag': '"48eeb659c0ec881228fc487a0bb0ad88"',
#    'x-amz-checksum-crc32': 'T6f3rQ==',
#    'x-amz-checksum-type': 'FULL_OBJECT',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'ETag': '"48eeb659c0ec881228fc487a0bb0ad88"',
#  'ChecksumCRC32': 'T6f3rQ==',
#  'ChecksumType': 'FULL_OBJECT',
#  'ServerSideEncryption': 'AES256'}

# %%
# %%html
#
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>
# Out:
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>
